# %% [markdown]
# # Mapping
#
# Transportation is about getting from place A to place B.  Therefore, most transportation data has a spatial component to it.  It is nice to be able to put these data on a map and see what is going on.  It is even better if we can put it on a map and interact with the data.  It would be even cooler if we could put our interactive map on a website to show it off!
#
# To do this, we are going to use a package called folium.  You can find the documentation here:
#
# https://folium.readthedocs.io/en/latest/
#
# And access it on github here:
#
# https://github.com/python-visualization/folium

# %% [markdown]
# ### Credits
#
# This lesson draws from the folium quickstart notebook, and from Vik Paruchuri DataQuest lesson:
#
# https://www.dataquest.io/blog/python-data-visualization-libraries/

# %% [markdown]
# ### A side note on static mapping
#
# Sometimes you may want to create a static map instead of an interactive map.  Interactive maps are nice for exploring your data, but static maps work well for an image that you can insert into a paper.  If you want to create static maps, then basemap is a good tool.  Here is a nice lesson focused on mapping earthquake activity:
#
# http://introtopython.org/visualization_earthquakes.html

# %% [markdown]
# ### OK, back to interactive mapping, because that's fun...
#
# It turns out that folium doesn't do much itself.  It is just a wrapper around something called leafletjs.  You can read more about that here:
#
# http://leafletjs.com/index.html
#
# Leaflet is a library in the JavaScript language.  JavaScript is the language used for most web applications.  We could do the same thing using JavaScript and leaflet directly, but then we would have to learn the syntax for another language.  That might not be too hard, but to keep it simple, we'll stick to the python wrapper for now.  It is good to be aware of, though, because if you want more options than folium allows, you can go directly to leaflet.
#
# What makes this possible is the fact that leaflet has a well-defined API.  That means that we can pass data back and forth, even from a different language.

# %% [markdown]
# ### Setup
#
# Start by installing folium using pip.  At a command prompt, type:
#
#     pip install folium
#
# Hmm...when I tried this on my desktop, I get an error that says:
#
#     PermissionError: [WinError 5] Access is denied: 'c:\\program files\\anaconda3\\Lib\\site-packages\\folium'
#
# It seems that it is trying to install something in the program files directory, which Windows has protected.  This will depend on the security settings on your machine.  If you get this error, open a command prompt as an administrator.  In the windows search bar, type cmd.  When you see the command prompt, right click, and select run as administrator.
#
# This did the trick, and now I get:
#
#     Successfully installed folium-0.2.1
#
# In addition, let's go to github and clone the folium repository (https://github.com/python-visualization/folium) to our desktop.  This gives us the source code on our local machine.  What we're really interested in is the examples folder, which gives us a bunch of jupyter notebooks showing how to do different stuff.  You are welcome to explore these as needed.
#
# You also need to install geopandas, which will make it easier to work with goegraphic data.  The pip installer doesn't work (the long explanation is here: http://geoffboeing.com/2014/09/using-geopandas-windows/), so we'll install using anaconda.  Type:
#
#     conda install -c conda-forge geopandas

# %% [markdown]
# Getting Started
# ---------------
#
# To create a base map, simply pass your starting coordinates to Folium:

# %%
import folium

# %%
m = folium.Map(location=[38.034,-84.500])

# %% [markdown]
# to display it in your notebook, just ask for the object representation.

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# To save it in a file

# %%
m.save('lex.html')

# %%
folium.Map?

# %% [markdown]
# We can use different backgrounds, or tilesets.  Several are built in.  Options include Stamen Terrain, Stamen Toner, Mapbox Bright, and Mapbox Control room tiles.

# %%
folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=13
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Pick one you like and work with that for the rest of the class.

# %% [markdown]
# Folium also supports Cloudmade and Mapbox custom tilesets- simply pass your key to the API_key keyword.  These are services where you can buy more backgrounds to make your maps look nice.
#
# ```python
# folium.Map(location=[45.5236, -122.6750],
#            tiles='Mapbox',
#            API_key='your.API.key')
# ```

# %% [markdown]
# ### Open flights
#
# Let's go back to our openflight data and make some maps.

# %%
import pandas as pd
import numpy as np

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["id", "name", "city", "country", "iata", "icao", "latitude", "longitude", "altitude","timezone", "dst", "tz", "type", "source"]

# Read in the airlines data.
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]

# Read in the routes data.
routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]

# %%
# let's peek at what we have
airports.head()
# Out:
#    id                                         name          city  \
# 0   1                               Goroka Airport        Goroka
# 1   2                               Madang Airport        Madang
# 2   3                 Mount Hagen Kagamuga Airport   Mount Hagen
# 3   4                               Nadzab Airport        Nadzab
# 4   5  Port Moresby Jacksons International Airport  Port Moresby
#
#             country iata  icao  latitude   longitude  altitude  timezone dst  \
# 0  Papua New Guinea  GKA  AYGA -6.081690  145.391998      5282      10.0   U
# 1  Papua New Guinea  MAG  AYMD -5.207080  145.789001        20      10.0   U
# 2  Papua New Guinea  HGU  AYMH -5.826790  144.296005      5388      10.0   U
# 3  Papua New Guinea  LAE  AYNZ -6.569803  146.725977       239      10.0   U
# 4  Papua New Guinea  POM  AYPY -9.443380  147.220001       146      10.0   U
#
#                      tz     type       source
# 0  Pacific/Port_Moresby  airport  OurAirports
# 1  Pacific/Port_Moresby  airport  OurAirports
# 2  Pacific/Port_Moresby  airport  OurAirports
# 3  Pacific/Port_Moresby  airport  OurAirports
# 4  Pacific/Port_Moresby  airport  OurAirports

# %%
airlines.head()
# Out:
#    id                                          name alias iata icao callsign  \
# 0  -1                                       Unknown   NaN    -  NaN      NaN
# 1   1                                Private flight   NaN    -  NaN      NaN
# 2   2                                   135 Airways   NaN  NaN  GNL  GENERAL
# 3   3                                 1Time Airline   NaN   1T  RNX  NEXTIME
# 4   4  2 Sqn No 1 Elementary Flying Training School   NaN  NaN  WYT      NaN
#
#           country active
# 0             NaN      Y
# 1             NaN      Y
# 2   United States      N
# 3    South Africa      Y
# 4  United Kingdom      N

# %%
routes.head()
# Out:
#   airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 0      2B       410.0    AER     2965.0  KZN   2990.0       NaN      0
# 1      2B       410.0    ASF     2966.0  KZN   2990.0       NaN      0
# 2      2B       410.0    ASF     2966.0  MRV   2962.0       NaN      0
# 3      2B       410.0    CEK     2968.0  KZN   2990.0       NaN      0
# 4      2B       410.0    CEK     2968.0  OVB   4078.0       NaN      0
#
#   equipment
# 0       CR2
# 1       CR2
# 2       CR2
# 3       CR2
# 4       CR2

# %% [markdown]
# Make a map with the airports on it.

# %%
# since there are a lot of airports, making the map can be slow
# so limit it to US airports
us_airports = airports[airports['country']=='United States']
len(us_airports)

# %%
# Get a basic world map.
# 30 centers the map E-W, and 0 is the equator
airports_map = folium.Map(location=[30, 0], zoom_start=2) #30 deg and 0 deg

# Loop through the airports, and draw each one as a marker on the map
# popup tells it what to display when you click on it
for name, row in us_airports.iterrows():
    
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        marker = folium.Marker([row["latitude"], row["longitude"]]) # we exclude popup=row['name'] here to get the map
        marker.add_to(airports_map) #add my marker to my map
        
# Save it to a file (it's kinda big for the notebook) #file can be saved as html
airports_map.save('airports.html') #to show it in explorer allow block contents

# %% [markdown]
# Hmm...it looks like there are airports everywhere!  Let's try again with smaller makers.
#
# We can also specify the color.  A list of custom colors is available here:
#
# http://www.w3schools.com/cssref/css_colors.asp

# %%
# over-write the airports_map, rather than just adding more markers to it. 
airports_map = folium.Map(location=[30, 0], zoom_start=2)

# use circle markers this time, with custom size and color
for name, row in us_airports.iterrows():
        
    # For some reason, this one airport causes issues with the map.
    if row["name"] != "South Pole Station":
        marker = folium.CircleMarker([row["latitude"], row["longitude"]], 
                                     radius=5,
                                     color='DarkCyan',
                                     fill_color='DarkCyan')
        marker.add_to(airports_map)
        
airports_map.save('airports.html')

# %% [markdown]
# You can also select icons to use as markers.  That code would look like:
#
#     marker = folium.Marker([row["latitude"], row["longitude"]],
#                            icon=folium.Icon(icon='cloud'),
#                            popup=row['name'])
#
# The list of icons comes from something called bootstrap, and can be found here:
#
# http://www.bootstrapicons.com/

# %% [markdown]
# Or you can use clusters of markers to clean up the map.  This will group them when you zoom out, similar to a Craigslist map.  You can see how to do that here:
#
# https://ocefpaf.github.io/python4oceanographers/blog/2015/12/14/geopandas_folium/
#
# You can clean up the rest of this airports map as part of your homework this week.

# %% [markdown]
# Let's draw the routes, but since we have lots, let's just start with the routes departing Lexington.

# %%
# Select the LEX routes, then join the source airports
lex_routes = routes[(routes['source']=="LEX")]
lex_routes = pd.merge(lex_routes, airports, left_on='source_id', right_on='id', how='left')

# %%
# join the destination airports.  Here we need to use the suffixes option, because 
# the column names overlap, and we want to distinguish between source and dest
lex_routes = pd.merge(lex_routes, airports, 
                      left_on='dest_id', 
                      right_on='id', 
                      how='left', 
                      suffixes=['_source','_dest'])

# %%
# here is what our data looks like
lex_routes
# Out:
#    airline  airline_id source_x source_id dest dest_id codeshare  stops  \
# 0       9E      3976.0      LEX      4017  ATL    3682       NaN      0
# 1       AA        24.0      LEX      4017  CLT    3876         Y      0
# 2       AA        24.0      LEX      4017  DFW    3670         Y      0
# 3       AA        24.0      LEX      4017  ORD    3830         Y      0
# 4       AF       137.0      LEX      4017  ATL    3682         Y      0
# 5       DL      2009.0      LEX      4017  ATL    3682       NaN      0
# 6       DL      2009.0      LEX      4017  DCA    3520         Y      0
# 7       DL      2009.0      LEX      4017  DTW    3645         Y      0
# 8       DL      2009.0      LEX      4017  LGA    3697       NaN      0
# 9       DL      2009.0      LEX      4017  MSP    3858         Y      0
# 10      G4        35.0      LEX      4017  FLL    3533       NaN      0
# 11      G4        35.0      LEX      4017  PGD    7056       NaN      0
# 12      G4        35.0      LEX      4017  PIE    3617       NaN      0
# 13      G4        35.0      LEX      4017  SFB    4167       NaN      0
# 14      KL      3090.0      LEX      4017  ATL    3682         Y      0
# 15      UA      5209.0      LEX      4017  IAH    3550         Y      0
# 16      UA      5209.0      LEX      4017  ORD    3830         Y      0
# 17      US      5265.0      LEX      4017  CLT    3876       NaN      0
# 18      US      5265.0      LEX      4017  DFW    3670       NaN      0
# 19      US      5265.0      LEX      4017  ORD    3830         Y      0
#
#       equipment  id_source     ...      iata_dest icao_dest latitude_dest  \
# 0           CRJ       4017     ...            ATL      KATL     33.636700
# 1       CR7 CRJ       4017     ...            CLT      KCLT     35.214001
# 2       ERD ER4       4017     ...            DFW      KDFW     32.896801
# 3       ERD ER4       4017     ...            ORD      KORD     41.978600
# 4       CRJ CR9       4017     ...            ATL      KATL     33.636700
# 5       M88 717       4017     ...            ATL      KATL     33.636700
# 6           CRJ       4017     ...            DCA      KDCA     38.852100
# 7   CR7 CRJ CR9       4017     ...            DTW      KDTW     42.212399
# 8           ERJ       4017     ...            LGA      KLGA     40.777199
# 9           CRJ       4017     ...            MSP      KMSP     44.882000
# 10          M80       4017     ...            FLL      KFLL     26.072599
# 11          M80       4017     ...            PGD      KPGD     26.920200
# 12          320       4017     ...            PIE      KPIE     27.910200
# 13      M80 320       4017     ...            SFB      KSFB     28.777599
# 14      CR9 CRJ       4017     ...            ATL      KATL     33.636700
# 15          ERJ       4017     ...            IAH      KIAH     29.984400
# 16      ERJ CRJ       4017     ...            ORD      KORD     41.978600
# 17          CR7       4017     ...            CLT      KCLT     35.214001
# 18          ERD       4017     ...            DFW      KDFW     32.896801
# 19      ERD ER4       4017     ...            ORD      KORD     41.978600
#
#    longitude_dest altitude_dest  timezone_dest  dst_dest           tz_dest  \
# 0      -84.428101          1026           -5.0         A  America/New_York
# 1      -80.943100           748           -5.0         A  America/New_York
# 2      -97.038002           607           -6.0         A   America/Chicago
# 3      -87.904800           672           -6.0         A   America/Chicago
# 4      -84.428101          1026           -5.0         A  America/New_York
# 5      -84.428101          1026           -5.0         A  America/New_York
# 6      -77.037697            15           -5.0         A  America/New_York
# 7      -83.353401           645           -5.0         A  America/New_York
# 8      -73.872597            21           -5.0         A  America/New_York
# 9      -93.221802           841           -6.0         A   America/Chicago
# 10     -80.152702             9           -5.0         A  America/New_York
# 11     -81.990501            26           -5.0         A  America/New_York
# 12     -82.687401            11           -5.0         A  America/New_York
# 13     -81.237503            55           -5.0         A  America/New_York
# 14     -84.428101          1026           -5.0         A  America/New_York
# 15     -95.341400            97           -6.0         A   America/Chicago
# 16     -87.904800           672           -6.0         A   America/Chicago
# 17     -80.943100           748           -5.0         A  America/New_York
# 18     -97.038002           607           -6.0         A   America/Chicago
# 19     -87.904800           672           -6.0         A   America/Chicago
#
#     type_dest       source
# 0     airport  OurAirports
# 1     airport  OurAirports
# 2     airport  OurAirports
# 3     airport  OurAirports
# 4     airport  OurAirports
# 5     airport  OurAirports
# 6     airport  OurAirports
# 7     airport  OurAirports
# 8     airport  OurAirports
# 9     airport  OurAirports
# 10    airport  OurAirports
# 11    airport  OurAirports
# 12    airport  OurAirports
# 13    airport  OurAirports
# 14    airport  OurAirports
# 15    airport  OurAirports
# 16    airport  OurAirports
# 17    airport  OurAirports
# 18    airport  OurAirports
# 19    airport  OurAirports
#
# [20 rows x 37 columns]

# %%
lex_routes.to_csv('lex_routes1.csv')

# %%
# It looks like source has some duplicate names.  Drop the values from the airports
# file ane keep the one from the routes file
lex_routes = lex_routes.drop(['source_y','source'], axis=1)
lex_routes = lex_routes.rename(columns={'source_x': 'source'})
lex_routes
# Out:
#    airline  airline_id source source_id dest dest_id codeshare  stops  \
# 0       9E      3976.0    LEX      4017  ATL    3682       NaN      0
# 1       AA        24.0    LEX      4017  CLT    3876         Y      0
# 2       AA        24.0    LEX      4017  DFW    3670         Y      0
# 3       AA        24.0    LEX      4017  ORD    3830         Y      0
# 4       AF       137.0    LEX      4017  ATL    3682         Y      0
# 5       DL      2009.0    LEX      4017  ATL    3682       NaN      0
# 6       DL      2009.0    LEX      4017  DCA    3520         Y      0
# 7       DL      2009.0    LEX      4017  DTW    3645         Y      0
# 8       DL      2009.0    LEX      4017  LGA    3697       NaN      0
# 9       DL      2009.0    LEX      4017  MSP    3858         Y      0
# 10      G4        35.0    LEX      4017  FLL    3533       NaN      0
# 11      G4        35.0    LEX      4017  PGD    7056       NaN      0
# 12      G4        35.0    LEX      4017  PIE    3617       NaN      0
# 13      G4        35.0    LEX      4017  SFB    4167       NaN      0
# 14      KL      3090.0    LEX      4017  ATL    3682         Y      0
# 15      UA      5209.0    LEX      4017  IAH    3550         Y      0
# 16      UA      5209.0    LEX      4017  ORD    3830         Y      0
# 17      US      5265.0    LEX      4017  CLT    3876       NaN      0
# 18      US      5265.0    LEX      4017  DFW    3670       NaN      0
# 19      US      5265.0    LEX      4017  ORD    3830         Y      0
#
#       equipment  id_source    ...      country_dest iata_dest icao_dest  \
# 0           CRJ       4017    ...     United States       ATL      KATL
# 1       CR7 CRJ       4017    ...     United States       CLT      KCLT
# 2       ERD ER4       4017    ...     United States       DFW      KDFW
# 3       ERD ER4       4017    ...     United States       ORD      KORD
# 4       CRJ CR9       4017    ...     United States       ATL      KATL
# 5       M88 717       4017    ...     United States       ATL      KATL
# 6           CRJ       4017    ...     United States       DCA      KDCA
# 7   CR7 CRJ CR9       4017    ...     United States       DTW      KDTW
# 8           ERJ       4017    ...     United States       LGA      KLGA
# 9           CRJ       4017    ...     United States       MSP      KMSP
# 10          M80       4017    ...     United States       FLL      KFLL
# 11          M80       4017    ...     United States       PGD      KPGD
# 12          320       4017    ...     United States       PIE      KPIE
# 13      M80 320       4017    ...     United States       SFB      KSFB
# 14      CR9 CRJ       4017    ...     United States       ATL      KATL
# 15          ERJ       4017    ...     United States       IAH      KIAH
# 16      ERJ CRJ       4017    ...     United States       ORD      KORD
# 17          CR7       4017    ...     United States       CLT      KCLT
# 18          ERD       4017    ...     United States       DFW      KDFW
# 19      ERD ER4       4017    ...     United States       ORD      KORD
#
#    latitude_dest longitude_dest  altitude_dest  timezone_dest  dst_dest  \
# 0      33.636700     -84.428101           1026           -5.0         A
# 1      35.214001     -80.943100            748           -5.0         A
# 2      32.896801     -97.038002            607           -6.0         A
# 3      41.978600     -87.904800            672           -6.0         A
# 4      33.636700     -84.428101           1026           -5.0         A
# 5      33.636700     -84.428101           1026           -5.0         A
# 6      38.852100     -77.037697             15           -5.0         A
# 7      42.212399     -83.353401            645           -5.0         A
# 8      40.777199     -73.872597             21           -5.0         A
# 9      44.882000     -93.221802            841           -6.0         A
# 10     26.072599     -80.152702              9           -5.0         A
# 11     26.920200     -81.990501             26           -5.0         A
# 12     27.910200     -82.687401             11           -5.0         A
# 13     28.777599     -81.237503             55           -5.0         A
# 14     33.636700     -84.428101           1026           -5.0         A
# 15     29.984400     -95.341400             97           -6.0         A
# 16     41.978600     -87.904800            672           -6.0         A
# 17     35.214001     -80.943100            748           -5.0         A
# 18     32.896801     -97.038002            607           -6.0         A
# 19     41.978600     -87.904800            672           -6.0         A
#
#              tz_dest type_dest
# 0   America/New_York   airport
# 1   America/New_York   airport
# 2    America/Chicago   airport
# 3    America/Chicago   airport
# 4   America/New_York   airport
# 5   America/New_York   airport
# 6   America/New_York   airport
# 7   America/New_York   airport
# 8   America/New_York   airport
# 9    America/Chicago   airport
# 10  America/New_York   airport
# 11  America/New_York   airport
# 12  America/New_York   airport
# 13  America/New_York   airport
# 14  America/New_York   airport
# 15   America/Chicago   airport
# 16   America/Chicago   airport
# 17  America/New_York   airport
# 18   America/Chicago   airport
# 19   America/Chicago   airport
#
# [20 rows x 35 columns]

# %%
one_stop_lex = lex_routes[(lex_routes['stops'] == 1 )]
one_stop_lex
# Out:
# Empty DataFrame
# Columns: [airline, airline_id, source, source_id, dest, dest_id, codeshare, stops, equipment, id_source, name_source, city_source, country_source, iata_source, icao_source, latitude_source, longitude_source, altitude_source, timezone_source, dst_source, tz_source, type_source, id_dest, name_dest, city_dest, country_dest, iata_dest, icao_dest, latitude_dest, longitude_dest, altitude_dest, timezone_dest, dst_dest, tz_dest, type_dest]
# Index: []
#
# [0 rows x 35 columns]

# %%
# Let's keep only one route between each airport pair
# so we don't have a bunch of lines on top of each other
# The subset option tells it to consider just those columns when determining
# what is a duplicate. 

lex_routes = lex_routes.drop_duplicates(subset=['source', 'dest'])
lex_routes
# Out:
#    airline  airline_id source source_id dest dest_id codeshare  stops  \
# 0       9E      3976.0    LEX      4017  ATL    3682       NaN      0
# 1       AA        24.0    LEX      4017  CLT    3876         Y      0
# 2       AA        24.0    LEX      4017  DFW    3670         Y      0
# 3       AA        24.0    LEX      4017  ORD    3830         Y      0
# 6       DL      2009.0    LEX      4017  DCA    3520         Y      0
# 7       DL      2009.0    LEX      4017  DTW    3645         Y      0
# 8       DL      2009.0    LEX      4017  LGA    3697       NaN      0
# 9       DL      2009.0    LEX      4017  MSP    3858         Y      0
# 10      G4        35.0    LEX      4017  FLL    3533       NaN      0
# 11      G4        35.0    LEX      4017  PGD    7056       NaN      0
# 12      G4        35.0    LEX      4017  PIE    3617       NaN      0
# 13      G4        35.0    LEX      4017  SFB    4167       NaN      0
# 15      UA      5209.0    LEX      4017  IAH    3550         Y      0
#
#       equipment  id_source    ...      country_dest iata_dest icao_dest  \
# 0           CRJ       4017    ...     United States       ATL      KATL
# 1       CR7 CRJ       4017    ...     United States       CLT      KCLT
# 2       ERD ER4       4017    ...     United States       DFW      KDFW
# 3       ERD ER4       4017    ...     United States       ORD      KORD
# 6           CRJ       4017    ...     United States       DCA      KDCA
# 7   CR7 CRJ CR9       4017    ...     United States       DTW      KDTW
# 8           ERJ       4017    ...     United States       LGA      KLGA
# 9           CRJ       4017    ...     United States       MSP      KMSP
# 10          M80       4017    ...     United States       FLL      KFLL
# 11          M80       4017    ...     United States       PGD      KPGD
# 12          320       4017    ...     United States       PIE      KPIE
# 13      M80 320       4017    ...     United States       SFB      KSFB
# 15          ERJ       4017    ...     United States       IAH      KIAH
#
#    latitude_dest longitude_dest  altitude_dest  timezone_dest  dst_dest  \
# 0      33.636700     -84.428101           1026           -5.0         A
# 1      35.214001     -80.943100            748           -5.0         A
# 2      32.896801     -97.038002            607           -6.0         A
# 3      41.978600     -87.904800            672           -6.0         A
# 6      38.852100     -77.037697             15           -5.0         A
# 7      42.212399     -83.353401            645           -5.0         A
# 8      40.777199     -73.872597             21           -5.0         A
# 9      44.882000     -93.221802            841           -6.0         A
# 10     26.072599     -80.152702              9           -5.0         A
# 11     26.920200     -81.990501             26           -5.0         A
# 12     27.910200     -82.687401             11           -5.0         A
# 13     28.777599     -81.237503             55           -5.0         A
# 15     29.984400     -95.341400             97           -6.0         A
#
#              tz_dest type_dest
# 0   America/New_York   airport
# 1   America/New_York   airport
# 2    America/Chicago   airport
# 3    America/Chicago   airport
# 6   America/New_York   airport
# 7   America/New_York   airport
# 8   America/New_York   airport
# 9    America/Chicago   airport
# 10  America/New_York   airport
# 11  America/New_York   airport
# 12  America/New_York   airport
# 13  America/New_York   airport
# 15   America/Chicago   airport
#
# [13 rows x 35 columns]

# %% [markdown]
# That looks better.  Now, let's create a map.  To avoid adding duplicate airports, we are going to use a container called a set.  A set is an unordered collection of unique elements.  This means we can keep adding LEX to the set, and end up with only 1 LEX in the end.

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f29018873801> in <module>()
#       1 # create a basic map, centered on Lexington
# ----> 2 lex_air = folium.Map(
#       3     location=[38.034,-84.500],
#       4     tiles='Stamen Toner',
#       5     zoom_start=4
#
# NameError: name 'folium' is not defined

# %%
# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # the parentheses in the indicate that we are adding a tuple to the route_set
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']        
        line = folium.PolyLine([(row["latitude_source"], row["longitude_source"]), 
                                (row["latitude_dest"], row["longitude_dest"])], 
                                weight=2)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air
lex_air.save('Lex airports.html')

# %% [markdown]
# That's cool.  But airplanes don't fly in a straight line.  They follow the great circle.  So when you fly from Chicago to London, you go over Greenland (which is really pretty on a clear day!).  Can we make the lines follow a great circle?
#
# It looks like there are some options here:
#
# http://gis.stackexchange.com/questions/47/what-tools-in-python-are-available-for-doing-great-circle-distance-line-creati
#
# Let's try one of them.

# %%
import pyproj

# when creating a function, it is good practice to define the API!
def getGreatCirclePoints(startlat, startlon, endlat, endlon): 
    """
    startlat - starting latitude 
    startlon - starting longitude 
    endlat   - ending latitude 
    endlon   - ending longitude 
    
    returns - a list of tuples, where each tuple is the lat-long for a point
              along the curve.  
    """
    # calculate distance between points
    g = pyproj.Geod(ellps='WGS84')
    (az12, az21, dist) = g.inv(startlon, startlat, endlon, endlat)

    # calculate line string along path with segments <= 20 km
    lonlats = g.npts(startlon, startlat, endlon, endlat,
                     1 + int(dist / 20000))

    # the npts function uses lon-lat, while the folium functions use lat-lon
    # This sort of thing is maddening!  What happens is the lines don't show
    # up on the map and you don't know why.  Learn from my mistakes
    latlons = []
    for lon_lat in lonlats: 
        
        # this is how you get values out of a tuple
        (lon, lat) = lon_lat
        
        # add them to our list
        latlons.append((lat, lon)) 
    
    # npts doesn't include start/end points, so prepend/append them
    latlons.insert(0, (startlat, startlon))
    latlons.append((endlat, endlon))
    
    return latlons

# %%
# any time we write a function, we should test that it works
p = getGreatCirclePoints(38.034, -84.500, 33.636700, -84.428101) 
p
# Out:
# [(38.034, -84.5),
#  (37.864933929949096, -84.49708149511396),
#  (37.695862920583586, -84.49417629534568),
#  (37.52678697986378, -84.49128425988357),
#  (37.35770611591111, -84.48840524964173),
#  (37.18862033700805, -84.48553912723197),
#  (37.019529651598035, -84.48268575693639),
#  (36.85043406828536, -84.47984500468044),
#  (36.68133359583508, -84.4770167380065),
#  (36.51222824317288, -84.474200826048),
#  (36.343118019385024, -84.47139713950395),
#  (36.17400293371815, -84.46860555061399),
#  (36.00488299557918, -84.46582593313389),
#  (35.83575821453518, -84.46305816231151),
#  (35.66662860031317, -84.46030211486323),
#  (35.49749416279997, -84.45755766895067),
#  (35.328354912042094, -84.45482470415813),
#  (35.15921085824549, -84.45210310147009),
#  (34.99006201177538, -84.44939274324938),
#  (34.82090838315612, -84.44669351321562),
#  (34.65174998307092, -84.44400529642411),
#  (34.48258682236167, -84.44132797924507),
#  (34.3134189120287, -84.43866144934323),
#  (34.14424626323062, -84.43600559565783),
#  (33.975068887284, -84.43336030838299),
#  (33.805886795663184, -84.4307254789483),
#  (33.6367, -84.428101)]

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)
lex_air
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define the map in the same way, but use great circles for the lines

# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in lex_routes.iterrows():
    
    if row['source'] not in airport_set: 
        popup_string = row['city_source'] + ' (' + row['source'] + ')'
        marker = folium.CircleMarker([row["latitude_source"], row["longitude_source"]], 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source'])
        
    if row['dest'] not in airport_set: 
        popup_string = row['city_dest'] + '(' + row['dest'] + ')'
        marker = folium.CircleMarker([row["latitude_dest"], row["longitude_dest"]], 
                                     color='MidnightBlue',
                                     fill_color='MidnightBlue', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['dest'])
    
    # PolyLine will accept a whole list of tuples, not just two
    if (row['source'],row['dest']) not in route_set:            
        popup_string = row['source'] + '-' + row['dest']       
        
        gc_points = getGreatCirclePoints(row["latitude_source"], 
                                         row["longitude_source"], 
                                         row["latitude_dest"], 
                                         row["longitude_dest"])
        
        line = folium.PolyLine(gc_points, weight=2, popup=popup_string)
        line.add_to(lex_air)
        route_set.add((row['source'],row['dest']))
        
lex_air
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# save it to its own file
lex_air.save("lex_air.html")

# %% [markdown]
# ### Your turn
#
# The above map shows everywhere you can get to from Lexington on a direct flight.  Your job is to:
#
# 1. Make a map of all the possible destinations with one transfer.
# 2. Make a map of all the possible desitnations with two transfers.
#
# Make the maps look nice!  Use color coding, vary the size of the features, or be selective about what you display in order to communicate the information effectively.
#
# Bonus: This is the air travel version of the Kevin Bacon game (https://oracleofbacon.org/).  What is the number N, such that you can reach every airport in the world with N or fewer transfers?
#
# Extra Bonus: Use this very important piece of knowledge to impress your friends at parties!

# %%
# These files use \N as a missing value indicator.  When reading the CSVs, we will tell
# it to use that value as missing or NA.  The double backslash is required because
# otherwise it will interpret \N as a carriage return. 

# Read in the airports data.
airports = pd.read_csv("data/airports.dat", header=None, na_values='\\N')
airports.columns = ["id", "name", "city", "country", "iata", "icao", "latitude", "longitude", "altitude","timezone", "dst", "tz", "type", "source"]

# Read in the airlines data.
airlines = pd.read_csv("data/airlines.dat", header=None, na_values='\\N')
airlines.columns = ["id", "name", "alias", "iata", "icao", "callsign", "country", "active"]

# Read in the routes data.
routes = pd.read_csv("data/routes.dat", header=None, na_values='\\N')
routes.columns = ["airline", "airline_id", "source", "source_id", "dest", "dest_id", "codeshare", "stops", "equipment"]

# %%
# Select the LEX routes, then join the source airports
lex_routes = routes[(routes['source']=="LEX")]
#lex_routes = pd.merge(lex_routes, airports, left_on='source_id', right_on='id', how='left')
lex_routes
# Out:
#       airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 3588       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 5763       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 5764       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 5765       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 9641       AF       137.0    LEX     4017.0  ATL   3682.0         Y      0
# 21095      DL      2009.0    LEX     4017.0  ATL   3682.0       NaN      0
# 21096      DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 21097      DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 21098      DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 21099      DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 29047      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 29048      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 29049      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 29050      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 36746      KL      3090.0    LEX     4017.0  ATL   3682.0         Y      0
# 57029      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
# 57030      UA      5209.0    LEX     4017.0  ORD   3830.0         Y      0
# 59544      US      5265.0    LEX     4017.0  CLT   3876.0       NaN      0
# 59545      US      5265.0    LEX     4017.0  DFW   3670.0       NaN      0
# 59546      US      5265.0    LEX     4017.0  ORD   3830.0         Y      0
#
#          equipment
# 3588           CRJ
# 5763       CR7 CRJ
# 5764       ERD ER4
# 5765       ERD ER4
# 9641       CRJ CR9
# 21095      M88 717
# 21096          CRJ
# 21097  CR7 CRJ CR9
# 21098          ERJ
# 21099          CRJ
# 29047          M80
# 29048          M80
# 29049          320
# 29050      M80 320
# 36746      CR9 CRJ
# 57029          ERJ
# 57030      ERJ CRJ
# 59544          CR7
# 59545          ERD
# 59546      ERD ER4

# %%
lex_routes = lex_routes.drop_duplicates(subset=['dest'])
lex_routes
# Out:
#       airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 3588       9E      3976.0    LEX     4017.0  ATL   3682.0       NaN      0
# 5763       AA        24.0    LEX     4017.0  CLT   3876.0         Y      0
# 5764       AA        24.0    LEX     4017.0  DFW   3670.0         Y      0
# 5765       AA        24.0    LEX     4017.0  ORD   3830.0         Y      0
# 21096      DL      2009.0    LEX     4017.0  DCA   3520.0         Y      0
# 21097      DL      2009.0    LEX     4017.0  DTW   3645.0         Y      0
# 21098      DL      2009.0    LEX     4017.0  LGA   3697.0       NaN      0
# 21099      DL      2009.0    LEX     4017.0  MSP   3858.0         Y      0
# 29047      G4        35.0    LEX     4017.0  FLL   3533.0       NaN      0
# 29048      G4        35.0    LEX     4017.0  PGD   7056.0       NaN      0
# 29049      G4        35.0    LEX     4017.0  PIE   3617.0       NaN      0
# 29050      G4        35.0    LEX     4017.0  SFB   4167.0       NaN      0
# 57029      UA      5209.0    LEX     4017.0  IAH   3550.0         Y      0
#
#          equipment
# 3588           CRJ
# 5763       CR7 CRJ
# 5764       ERD ER4
# 5765       ERD ER4
# 21096          CRJ
# 21097  CR7 CRJ CR9
# 21098          ERJ
# 21099          CRJ
# 29047          M80
# 29048          M80
# 29049          320
# 29050      M80 320
# 57029          ERJ

# %%
lex_direct=lex_routes.dest.unique()
lex_direct
# Out:
# array(['ATL', 'CLT', 'DFW', 'ORD', 'DCA', 'DTW', 'LGA', 'MSP', 'FLL',
#        'PGD', 'PIE', 'SFB', 'IAH'], dtype=object)

# %%
lex_direct_routes = routes[routes['source'].isin(lex_direct)]
lex_direct_routes
# Out:
#       airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 265        3E     10739.0    ORD     3830.0  BRL   5726.0       NaN      0
# 266        3E     10739.0    ORD     3830.0  DEC   4042.0       NaN      0
# 443        3M     20710.0    ATL     3682.0  LWB   6958.0       NaN      0
# 444        3M     20710.0    ATL     3682.0  MCN   3754.0       NaN      0
# 445        3M     20710.0    ATL     3682.0  MEI   4335.0       NaN      0
# 446        3M     20710.0    ATL     3682.0  MSL   5756.0       NaN      0
# 447        3M     20710.0    ATL     3682.0  PIB   5759.0       NaN      0
# 448        3M     20710.0    ATL     3682.0  TUP   5773.0       NaN      0
# 455        3M     20710.0    FLL     3533.0  BIM   1937.0       NaN      0
# 456        3M     20710.0    FLL     3533.0  ELH   1943.0       NaN      0
# 457        3M     20710.0    FLL     3533.0  EYW   3875.0       NaN      0
# 458        3M     20710.0    FLL     3533.0  FPO   1948.0       NaN      0
# 459        3M     20710.0    FLL     3533.0  GGT   1941.0       NaN      0
# 460        3M     20710.0    FLL     3533.0  GHB   1944.0       NaN      0
# 461        3M     20710.0    FLL     3533.0  MCO   3878.0       NaN      0
# 462        3M     20710.0    FLL     3533.0  MHH   1930.0       NaN      0
# 463        3M     20710.0    FLL     3533.0  TCB   1934.0       NaN      0
# 464        3M     20710.0    FLL     3533.0  TPA   3646.0       NaN      0
# 1059       4M      3201.0    DFW     3670.0  EZE   3988.0         Y      0
# 2781       7I     18944.0    CLT     3876.0  CUR   2897.0       NaN      0
# 3559       9E      3976.0    ATL     3682.0  AZO   4039.0       NaN      0
# 3560       9E      3976.0    ATL     3682.0  CHA   3578.0       NaN      0
# 3561       9E      3976.0    ATL     3682.0  CID   4043.0       NaN      0
# 3562       9E      3976.0    ATL     3682.0  CRW   4285.0       NaN      0
# 3563       9E      3976.0    ATL     3682.0  CVG   3488.0       NaN      0
# 3564       9E      3976.0    ATL     3682.0  EVV   4018.0       NaN      0
# 3565       9E      3976.0    ATL     3682.0  FWA   4041.0       NaN      0
# 3566       9E      3976.0    ATL     3682.0  GSO   4008.0       NaN      0
# 3567       9E      3976.0    ATL     3682.0  GSP   4034.0       NaN      0
# 3568       9E      3976.0    ATL     3682.0  LAN   3544.0       NaN      0
# ...       ...         ...    ...        ...  ...      ...       ...    ...
# 64168      WN      4547.0    MSP     3858.0  DEN   3751.0       NaN      0
# 64169      WN      4547.0    MSP     3858.0  MCI   3458.0       NaN      0
# 64170      WN      4547.0    MSP     3858.0  MCO   3878.0       NaN      0
# 64171      WN      4547.0    MSP     3858.0  MDW   3747.0       NaN      0
# 64172      WN      4547.0    MSP     3858.0  MKE   3717.0       NaN      0
# 64173      WN      4547.0    MSP     3858.0  PHX   3462.0       NaN      0
# 64174      WN      4547.0    MSP     3858.0  STL   3678.0       NaN      0
# 64569      WS      5416.0    ATL     3682.0  JFK   3797.0         Y      0
# 64570      WS      5416.0    ATL     3682.0  LGA   3697.0         Y      0
# 64571      WS      5416.0    ATL     3682.0  YYZ    193.0         Y      0
# 64584      WS      5416.0    DFW     3670.0  YUL    146.0         Y      0
# 64585      WS      5416.0    DFW     3670.0  YVR    156.0         Y      0
# 64586      WS      5416.0    DFW     3670.0  YYC    178.0       NaN      0
# 64587      WS      5416.0    DFW     3670.0  YYZ    193.0         Y      0
# 64588      WS      5416.0    DTW     3645.0  YYZ    193.0         Y      0
# 64589      WS      5416.0    FLL     3533.0  YUL    146.0       NaN      0
# 64590      WS      5416.0    FLL     3533.0  YYZ    193.0       NaN      0
# 64611      WS      5416.0    LGA     3697.0  ATL   3682.0         Y      0
# 64612      WS      5416.0    LGA     3697.0  MSY   3861.0         Y      0
# 64613      WS      5416.0    LGA     3697.0  YHZ     73.0         Y      0
# 64614      WS      5416.0    LGA     3697.0  YUL    146.0         Y      0
# 64615      WS      5416.0    LGA     3697.0  YYZ    193.0       NaN      0
# 64628      WS      5416.0    MSP     3858.0  YUL    146.0         Y      0
# 64629      WS      5416.0    MSP     3858.0  YYZ    193.0         Y      0
# 64635      WS      5416.0    ORD     3830.0  YUL    146.0         Y      0
# 64636      WS      5416.0    ORD     3830.0  YVR    156.0       NaN      0
# 64637      WS      5416.0    ORD     3830.0  YYC    178.0       NaN      0
# 64638      WS      5416.0    ORD     3830.0  YYZ    193.0         Y      0
# 65825      Y4      5325.0    ORD     3830.0  MEX   1824.0       NaN      0
# 67553      ZK      2607.0    MSP     3858.0  ATY   5721.0       NaN      0
#
#                          equipment
# 265                            CNC
# 266                            CNC
# 443                            SF3
# 444                            SF3
# 445                            SF3
# 446                            SF3
# 447                            SF3
# 448                            SF3
# 455                            SF3
# 456                            SF3
# 457                            SF3
# 458                            SF3
# 459                            SF3
# 460                            SF3
# 461                            SF3
# 462                            SF3
# 463                            SF3
# 464                            SF3
# 1059                           777
# 2781                           M83
# 3559                           CRJ
# 3560                           CRJ
# 3561                           CRJ
# 3562                           CRJ
# 3563                          CR9
# 3564                           CRJ
# 3565                           CRJ
# 3566                           CR9
# 3567                           CRJ
# 3568                           CRJ
# ...                            ...
# 64168                  73W 73H 73C
# 64169                      73C 73W
# 64170                          73W
# 64171                      73W 73H
# 64172                      73W 73C
# 64173                      73C 73W
# 64174                      73W 733
# 64569                          738
# 64570  320 757 M88 738 739 73H 73W
# 64571                      CR7 CR9
# 64584                          738
# 64585                          738
# 64586                          73W
# 64587                          319
# 64588                      CR7 CRJ
# 64589                          73W
# 64590                      73H 73W
# 64611      M88 757 320 738 739 73W
# 64612                      319 CR9
# 64613                          CR7
# 64614                      ERJ CR7
# 64615                      736 73W
# 64628                          CR9
# 64629                          CRJ
# 64635                          CRJ
# 64636                          73W
# 64637                          73W
# 64638                  CR7 E75 ER4
# 65825                          320
# 67553                          BE1
#
# [3558 rows x 9 columns]

# %%
lex_direct_routes=lex_direct_routes[['source','source_id','dest','dest_id']]

# %%
lex_direct_routes.columns=['layover','layover_id','dest','dest_id']

# %%
lex_direct_routes.head()
# Out:
#     layover  layover_id dest  dest_id
# 265     ORD      3830.0  BRL   5726.0
# 266     ORD      3830.0  DEC   4042.0
# 443     ATL      3682.0  LWB   6958.0
# 444     ATL      3682.0  MCN   3754.0
# 445     ATL      3682.0  MEI   4335.0

# %%
lex_routes=lex_routes[['source','source_id','dest','dest_id']]
lex_routes.columns=['source','source_id','layover','layover_id']
lex_routes.head()
# Out:
#       source  source_id layover  layover_id
# 3588     LEX     4017.0     ATL      3682.0
# 5763     LEX     4017.0     CLT      3876.0
# 5764     LEX     4017.0     DFW      3670.0
# 5765     LEX     4017.0     ORD      3830.0
# 21096    LEX     4017.0     DCA      3520.0

# %%
one_trsfr_routes=lex_routes.join(lex_direct_routes,how='right',on='layover',lsuffix='lex_routes',rsuffix='lex_direct_routes')
one_trsfr_routes
# Out:
#        layover source  source_id layoverlex_routes  layover_idlex_routes  \
# 57029      265    NaN        NaN               NaN                   NaN
# 57029      266    NaN        NaN               NaN                   NaN
# 57029      443    NaN        NaN               NaN                   NaN
# 57029      444    NaN        NaN               NaN                   NaN
# 57029      445    NaN        NaN               NaN                   NaN
# 57029      446    NaN        NaN               NaN                   NaN
# 57029      447    NaN        NaN               NaN                   NaN
# 57029      448    NaN        NaN               NaN                   NaN
# 57029      455    NaN        NaN               NaN                   NaN
# 57029      456    NaN        NaN               NaN                   NaN
# 57029      457    NaN        NaN               NaN                   NaN
# 57029      458    NaN        NaN               NaN                   NaN
# 57029      459    NaN        NaN               NaN                   NaN
# 57029      460    NaN        NaN               NaN                   NaN
# 57029      461    NaN        NaN               NaN                   NaN
# 57029      462    NaN        NaN               NaN                   NaN
# 57029      463    NaN        NaN               NaN                   NaN
# 57029      464    NaN        NaN               NaN                   NaN
# 57029     1059    NaN        NaN               NaN                   NaN
# 57029     2781    NaN        NaN               NaN                   NaN
# 57029     3559    NaN        NaN               NaN                   NaN
# 57029     3560    NaN        NaN               NaN                   NaN
# 57029     3561    NaN        NaN               NaN                   NaN
# 57029     3562    NaN        NaN               NaN                   NaN
# 57029     3563    NaN        NaN               NaN                   NaN
# 57029     3564    NaN        NaN               NaN                   NaN
# 57029     3565    NaN        NaN               NaN                   NaN
# 57029     3566    NaN        NaN               NaN                   NaN
# 57029     3567    NaN        NaN               NaN                   NaN
# 57029     3568    NaN        NaN               NaN                   NaN
# ...        ...    ...        ...               ...                   ...
# 57029    64168    NaN        NaN               NaN                   NaN
# 57029    64169    NaN        NaN               NaN                   NaN
# 57029    64170    NaN        NaN               NaN                   NaN
# 57029    64171    NaN        NaN               NaN                   NaN
# 57029    64172    NaN        NaN               NaN                   NaN
# 57029    64173    NaN        NaN               NaN                   NaN
# 57029    64174    NaN        NaN               NaN                   NaN
# 57029    64569    NaN        NaN               NaN                   NaN
# 57029    64570    NaN        NaN               NaN                   NaN
# 57029    64571    NaN        NaN               NaN                   NaN
# 57029    64584    NaN        NaN               NaN                   NaN
# 57029    64585    NaN        NaN               NaN                   NaN
# 57029    64586    NaN        NaN               NaN                   NaN
# 57029    64587    NaN        NaN               NaN                   NaN
# 57029    64588    NaN        NaN               NaN                   NaN
# 57029    64589    NaN        NaN               NaN                   NaN
# 57029    64590    NaN        NaN               NaN                   NaN
# 57029    64611    NaN        NaN               NaN                   NaN
# 57029    64612    NaN        NaN               NaN                   NaN
# 57029    64613    NaN        NaN               NaN                   NaN
# 57029    64614    NaN        NaN               NaN                   NaN
# 57029    64615    NaN        NaN               NaN                   NaN
# 57029    64628    NaN        NaN               NaN                   NaN
# 57029    64629    NaN        NaN               NaN                   NaN
# 57029    64635    NaN        NaN               NaN                   NaN
# 57029    64636    NaN        NaN               NaN                   NaN
# 57029    64637    NaN        NaN               NaN                   NaN
# 57029    64638    NaN        NaN               NaN                   NaN
# 57029    65825    NaN        NaN               NaN                   NaN
# 57029    67553    NaN        NaN               NaN                   NaN
#
#       layoverlex_direct_routes  layover_idlex_direct_routes dest  dest_id
# 57029                      ORD                       3830.0  BRL   5726.0
# 57029                      ORD                       3830.0  DEC   4042.0
# 57029                      ATL                       3682.0  LWB   6958.0
# 57029                      ATL                       3682.0  MCN   3754.0
# 57029                      ATL                       3682.0  MEI   4335.0
# 57029                      ATL                       3682.0  MSL   5756.0
# 57029                      ATL                       3682.0  PIB   5759.0
# 57029                      ATL                       3682.0  TUP   5773.0
# 57029                      FLL                       3533.0  BIM   1937.0
# 57029                      FLL                       3533.0  ELH   1943.0
# 57029                      FLL                       3533.0  EYW   3875.0
# 57029                      FLL                       3533.0  FPO   1948.0
# 57029                      FLL                       3533.0  GGT   1941.0
# 57029                      FLL                       3533.0  GHB   1944.0
# 57029                      FLL                       3533.0  MCO   3878.0
# 57029                      FLL                       3533.0  MHH   1930.0
# 57029                      FLL                       3533.0  TCB   1934.0
# 57029                      FLL                       3533.0  TPA   3646.0
# 57029                      DFW                       3670.0  EZE   3988.0
# 57029                      CLT                       3876.0  CUR   2897.0
# 57029                      ATL                       3682.0  AZO   4039.0
# 57029                      ATL                       3682.0  CHA   3578.0
# 57029                      ATL                       3682.0  CID   4043.0
# 57029                      ATL                       3682.0  CRW   4285.0
# 57029                      ATL                       3682.0  CVG   3488.0
# 57029                      ATL                       3682.0  EVV   4018.0
# 57029                      ATL                       3682.0  FWA   4041.0
# 57029                      ATL                       3682.0  GSO   4008.0
# 57029                      ATL                       3682.0  GSP   4034.0
# 57029                      ATL                       3682.0  LAN   3544.0
# ...                        ...                          ...  ...      ...
# 57029                      MSP                       3858.0  DEN   3751.0
# 57029                      MSP                       3858.0  MCI   3458.0
# 57029                      MSP                       3858.0  MCO   3878.0
# 57029                      MSP                       3858.0  MDW   3747.0
# 57029                      MSP                       3858.0  MKE   3717.0
# 57029                      MSP                       3858.0  PHX   3462.0
# 57029                      MSP                       3858.0  STL   3678.0
# 57029                      ATL                       3682.0  JFK   3797.0
# 57029                      ATL                       3682.0  LGA   3697.0
# 57029                      ATL                       3682.0  YYZ    193.0
# 57029                      DFW                       3670.0  YUL    146.0
# 57029                      DFW                       3670.0  YVR    156.0
# 57029                      DFW                       3670.0  YYC    178.0
# 57029                      DFW                       3670.0  YYZ    193.0
# 57029                      DTW                       3645.0  YYZ    193.0
# 57029                      FLL                       3533.0  YUL    146.0
# 57029                      FLL                       3533.0  YYZ    193.0
# 57029                      LGA                       3697.0  ATL   3682.0
# 57029                      LGA                       3697.0  MSY   3861.0
# 57029                      LGA                       3697.0  YHZ     73.0
# 57029                      LGA                       3697.0  YUL    146.0
# 57029                      LGA                       3697.0  YYZ    193.0
# 57029                      MSP                       3858.0  YUL    146.0
# 57029                      MSP                       3858.0  YYZ    193.0
# 57029                      ORD                       3830.0  YUL    146.0
# 57029                      ORD                       3830.0  YVR    156.0
# 57029                      ORD                       3830.0  YYC    178.0
# 57029                      ORD                       3830.0  YYZ    193.0
# 57029                      ORD                       3830.0  MEX   1824.0
# 57029                      MSP                       3858.0  ATY   5721.0
#
# [3558 rows x 9 columns]

# %%
one_trsfr_routes=one_trsfr_routes[['layoverlex_direct_routes','layover_idlex_direct_routes','dest','dest_id']]

# %%
one_trsfr_routes['source']='LEX'
one_trsfr_routes['source_id']='4017.0'
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
one_trsfr_routes.columns=['layover','layover_id','dest','dest_id','source','source_id']

# %%
one_trsfr_routes.head()
# Out:
#       layover  layover_id dest  dest_id source source_id
# 57029     ORD      3830.0  BRL   5726.0    LEX    4017.0
# 57029     ORD      3830.0  DEC   4042.0    LEX    4017.0
# 57029     ATL      3682.0  LWB   6958.0    LEX    4017.0
# 57029     ATL      3682.0  MCN   3754.0    LEX    4017.0
# 57029     ATL      3682.0  MEI   4335.0    LEX    4017.0

# %%
# join the destination airports.  Here we need to use the suffixes option, because 
# the column names overlap, and we want to distinguish between source and dest
one_trsfr_allroutes = pd.merge(one_trsfr_routes, airports, 
                      left_on='dest_id', 
                      right_on='id', 
                      how='left', 
                      suffixes=['_source','_dest'])
one_trsfr_allroutes
# Out:
#      layover  layover_id dest dest_id source_source source_id      id  \
# 0        ORD      3830.0  BRL    5726           LEX    4017.0  5726.0
# 1        ORD      3830.0  DEC    4042           LEX    4017.0  4042.0
# 2        ATL      3682.0  LWB    6958           LEX    4017.0  6958.0
# 3        ATL      3682.0  MCN    3754           LEX    4017.0  3754.0
# 4        ATL      3682.0  MEI    4335           LEX    4017.0  4335.0
# 5        ATL      3682.0  MSL    5756           LEX    4017.0  5756.0
# 6        ATL      3682.0  PIB    5759           LEX    4017.0  5759.0
# 7        ATL      3682.0  TUP    5773           LEX    4017.0  5773.0
# 8        FLL      3533.0  BIM    1937           LEX    4017.0  1937.0
# 9        FLL      3533.0  ELH    1943           LEX    4017.0  1943.0
# 10       FLL      3533.0  EYW    3875           LEX    4017.0  3875.0
# 11       FLL      3533.0  FPO    1948           LEX    4017.0  1948.0
# 12       FLL      3533.0  GGT    1941           LEX    4017.0  1941.0
# 13       FLL      3533.0  GHB    1944           LEX    4017.0  1944.0
# 14       FLL      3533.0  MCO    3878           LEX    4017.0  3878.0
# 15       FLL      3533.0  MHH    1930           LEX    4017.0  1930.0
# 16       FLL      3533.0  TCB    1934           LEX    4017.0  1934.0
# 17       FLL      3533.0  TPA    3646           LEX    4017.0  3646.0
# 18       DFW      3670.0  EZE    3988           LEX    4017.0  3988.0
# 19       CLT      3876.0  CUR    2897           LEX    4017.0  2897.0
# 20       ATL      3682.0  AZO    4039           LEX    4017.0  4039.0
# 21       ATL      3682.0  CHA    3578           LEX    4017.0  3578.0
# 22       ATL      3682.0  CID    4043           LEX    4017.0  4043.0
# 23       ATL      3682.0  CRW    4285           LEX    4017.0  4285.0
# 24       ATL      3682.0  CVG    3488           LEX    4017.0  3488.0
# 25       ATL      3682.0  EVV    4018           LEX    4017.0  4018.0
# 26       ATL      3682.0  FWA    4041           LEX    4017.0  4041.0
# 27       ATL      3682.0  GSO    4008           LEX    4017.0  4008.0
# 28       ATL      3682.0  GSP    4034           LEX    4017.0  4034.0
# 29       ATL      3682.0  LAN    3544           LEX    4017.0  3544.0
# ...      ...         ...  ...     ...           ...       ...     ...
# 3528     MSP      3858.0  DEN    3751           LEX    4017.0  3751.0
# 3529     MSP      3858.0  MCI    3458           LEX    4017.0  3458.0
# 3530     MSP      3858.0  MCO    3878           LEX    4017.0  3878.0
# 3531     MSP      3858.0  MDW    3747           LEX    4017.0  3747.0
# 3532     MSP      3858.0  MKE    3717           LEX    4017.0  3717.0
# 3533     MSP      3858.0  PHX    3462           LEX    4017.0  3462.0
# 3534     MSP      3858.0  STL    3678           LEX    4017.0  3678.0
# 3535     ATL      3682.0  JFK    3797           LEX    4017.0  3797.0
# 3536     ATL      3682.0  LGA    3697           LEX    4017.0  3697.0
# 3537     ATL      3682.0  YYZ     193           LEX    4017.0   193.0
# 3538     DFW      3670.0  YUL     146           LEX    4017.0   146.0
# 3539     DFW      3670.0  YVR     156           LEX    4017.0   156.0
# 3540     DFW      3670.0  YYC     178           LEX    4017.0   178.0
# 3541     DFW      3670.0  YYZ     193           LEX    4017.0   193.0
# 3542     DTW      3645.0  YYZ     193           LEX    4017.0   193.0
# 3543     FLL      3533.0  YUL     146           LEX    4017.0   146.0
# 3544     FLL      3533.0  YYZ     193           LEX    4017.0   193.0
# 3545     LGA      3697.0  ATL    3682           LEX    4017.0  3682.0
# 3546     LGA      3697.0  MSY    3861           LEX    4017.0  3861.0
# 3547     LGA      3697.0  YHZ      73           LEX    4017.0    73.0
# 3548     LGA      3697.0  YUL     146           LEX    4017.0   146.0
# 3549     LGA      3697.0  YYZ     193           LEX    4017.0   193.0
# 3550     MSP      3858.0  YUL     146           LEX    4017.0   146.0
# 3551     MSP      3858.0  YYZ     193           LEX    4017.0   193.0
# 3552     ORD      3830.0  YUL     146           LEX    4017.0   146.0
# 3553     ORD      3830.0  YVR     156           LEX    4017.0   156.0
# 3554     ORD      3830.0  YYC     178           LEX    4017.0   178.0
# 3555     ORD      3830.0  YYZ     193           LEX    4017.0   193.0
# 3556     ORD      3830.0  MEX    1824           LEX    4017.0  1824.0
# 3557     MSP      3858.0  ATY    5721           LEX    4017.0  5721.0
#
#                                                    name                city  \
# 0                       Southeast Iowa Regional Airport          Burlington
# 1                                       Decatur Airport             Decatur
# 2                             Greenbrier Valley Airport           Lewisburg
# 3                       Middle Georgia Regional Airport               Macon
# 4                                             Key Field            Meridian
# 5                    Northwest Alabama Regional Airport       Muscle Shoals
# 6                   Hattiesburg Laurel Regional Airport  Hattiesburg/Laurel
# 7                               Tupelo Regional Airport              Tupelo
# 8                                  South Bimini Airport          Alice Town
# 9                               North Eleuthera Airport     North Eleuthera
# 10                       Key West International Airport            Key West
# 11                   Grand Bahama International Airport            Freeport
# 12                          Exuma International Airport         Great Exuma
# 13                           Governor's Harbour Airport   Governor's Harbor
# 14                        Orlando International Airport             Orlando
# 15                  Marsh Harbour International Airport        Marsh Harbor
# 16                                 Treasure Cay Airport        Treasure Cay
# 17                          Tampa International Airport               Tampa
# 18             Ministro Pistarini International Airport        Buenos Aires
# 19                           Hato International Airport          Willemstad
# 20         Kalamazoo Battle Creek International Airport           Kalamazoo
# 21                                         Lovell Field         Chattanooga
# 22                             The Eastern Iowa Airport        Cedar Rapids
# 23                                       Yeager Airport          Charleston
# 24    Cincinnati Northern Kentucky International Air...          Cincinnati
# 25                          Evansville Regional Airport          Evansville
# 26                     Fort Wayne International Airport          Fort Wayne
# 27                 Piedmont Triad International Airport          Greensboro
# 28         Greenville Spartanburg International Airport          Greenville
# 29                                 Capital City Airport             Lansing
# ...                                                 ...                 ...
# 3528                       Denver International Airport              Denver
# 3529                  Kansas City International Airport         Kansas City
# 3530                      Orlando International Airport             Orlando
# 3531               Chicago Midway International Airport             Chicago
# 3532             General Mitchell International Airport           Milwaukee
# 3533           Phoenix Sky Harbor International Airport             Phoenix
# 3534             Lambert St Louis International Airport           St. Louis
# 3535               John F Kennedy International Airport            New York
# 3536                                 La Guardia Airport            New York
# 3537            Lester B. Pearson International Airport             Toronto
# 3538  Montreal / Pierre Elliott Trudeau Internationa...            Montreal
# 3539                    Vancouver International Airport           Vancouver
# 3540                      Calgary International Airport             Calgary
# 3541            Lester B. Pearson International Airport             Toronto
# 3542            Lester B. Pearson International Airport             Toronto
# 3543  Montreal / Pierre Elliott Trudeau Internationa...            Montreal
# 3544            Lester B. Pearson International Airport             Toronto
# 3545   Hartsfield Jackson Atlanta International Airport             Atlanta
# 3546  Louis Armstrong New Orleans International Airport         New Orleans
# 3547          Halifax / Stanfield International Airport             Halifax
# 3548  Montreal / Pierre Elliott Trudeau Internationa...            Montreal
# 3549            Lester B. Pearson International Airport             Toronto
# 3550  Montreal / Pierre Elliott Trudeau Internationa...            Montreal
# 3551            Lester B. Pearson International Airport             Toronto
# 3552  Montreal / Pierre Elliott Trudeau Internationa...            Montreal
# 3553                    Vancouver International Airport           Vancouver
# 3554                      Calgary International Airport             Calgary
# 3555            Lester B. Pearson International Airport             Toronto
# 3556     Licenciado Benito Juarez International Airport         Mexico City
# 3557                         Watertown Regional Airport           Watertown
#
#                    country iata  icao   latitude   longitude  altitude  \
# 0            United States  BRL  KBRL  40.783199  -91.125504     698.0
# 1            United States  DEC  KDEC  39.834599  -88.865700     682.0
# 2            United States  LWB  KLWB  37.858299  -80.399498    2302.0
# 3            United States  MCN  KMCN  32.692799  -83.649200     354.0
# 4            United States  MEI  KMEI  32.332600  -88.751900     297.0
# 5            United States  MSL  KMSL  34.745300  -87.610199     551.0
# 6            United States  PIB  KPIB  31.467100  -89.337097     298.0
# 7            United States  TUP  KTUP  34.268101  -88.769897     346.0
# 8                  Bahamas  BIM  MYBS  25.699900  -79.264702      10.0
# 9                  Bahamas  ELH  MYEH  25.474899  -76.683502      13.0
# 10           United States  EYW  KEYW  24.556101  -81.759598       3.0
# 11                 Bahamas  FPO  MYGF  26.558701  -78.695602       7.0
# 12                 Bahamas  GGT  MYEF  23.562599  -75.877998       9.0
# 13                 Bahamas  GHB  MYEM  25.284700  -76.331001      26.0
# 14           United States  MCO  KMCO  28.429399  -81.308998      96.0
# 15                 Bahamas  MHH  MYAM  26.511400  -77.083504       6.0
# 16                 Bahamas  TCB  MYAT  26.745300  -77.391296       8.0
# 17           United States  TPA  KTPA  27.975500  -82.533203      26.0
# 18               Argentina  EZE  SAEZ -34.822200  -58.535800      67.0
# 19    Netherlands Antilles  CUR  TNCC  12.188900  -68.959801      29.0
# 20           United States  AZO  KAZO  42.234901  -85.552101     874.0
# 21           United States  CHA  KCHA  35.035301  -85.203796     683.0
# 22           United States  CID  KCID  41.884701  -91.710800     869.0
# 23           United States  CRW  KCRW  38.373100  -81.593201     981.0
# 24           United States  CVG  KCVG  39.048801  -84.667801     896.0
# 25           United States  EVV  KEVV  38.036999  -87.532402     418.0
# 26           United States  FWA  KFWA  40.978500  -85.195099     814.0
# 27           United States  GSO  KGSO  36.097801  -79.937302     925.0
# 28           United States  GSP  KGSP  34.895699  -82.218903     964.0
# 29           United States  LAN  KLAN  42.778702  -84.587402     861.0
# ...                    ...  ...   ...        ...         ...       ...
# 3528         United States  DEN  KDEN  39.861698 -104.672997    5431.0
# 3529         United States  MCI  KMCI  39.297600  -94.713898    1026.0
# 3530         United States  MCO  KMCO  28.429399  -81.308998      96.0
# 3531         United States  MDW  KMDW  41.785999  -87.752403     620.0
# 3532         United States  MKE  KMKE  42.947201  -87.896599     723.0
# 3533         United States  PHX  KPHX  33.434299 -112.012001    1135.0
# 3534         United States  STL  KSTL  38.748699  -90.370003     618.0
# 3535         United States  JFK  KJFK  40.639801  -73.778900      13.0
# 3536         United States  LGA  KLGA  40.777199  -73.872597      21.0
# 3537                Canada  YYZ  CYYZ  43.677200  -79.630600     569.0
# 3538                Canada  YUL  CYUL  45.470600  -73.740799     118.0
# 3539                Canada  YVR  CYVR  49.193901 -123.183998      14.0
# 3540                Canada  YYC  CYYC  51.113899 -114.019997    3557.0
# 3541                Canada  YYZ  CYYZ  43.677200  -79.630600     569.0
# 3542                Canada  YYZ  CYYZ  43.677200  -79.630600     569.0
# 3543                Canada  YUL  CYUL  45.470600  -73.740799     118.0
# 3544                Canada  YYZ  CYYZ  43.677200  -79.630600     569.0
# 3545         United States  ATL  KATL  33.636700  -84.428101    1026.0
# 3546         United States  MSY  KMSY  29.993401  -90.258003       4.0
# 3547                Canada  YHZ  CYHZ  44.880798  -63.508598     477.0
# 3548                Canada  YUL  CYUL  45.470600  -73.740799     118.0
# 3549                Canada  YYZ  CYYZ  43.677200  -79.630600     569.0
# 3550                Canada  YUL  CYUL  45.470600  -73.740799     118.0
# 3551                Canada  YYZ  CYYZ  43.677200  -79.630600     569.0
# 3552                Canada  YUL  CYUL  45.470600  -73.740799     118.0
# 3553                Canada  YVR  CYVR  49.193901 -123.183998      14.0
# 3554                Canada  YYC  CYYC  51.113899 -114.019997    3557.0
# 3555                Canada  YYZ  CYYZ  43.677200  -79.630600     569.0
# 3556                Mexico  MEX  MMMX  19.436300  -99.072098    7316.0
# 3557         United States  ATY  KATY  44.914001  -97.154701    1749.0
#
#       timezone dst                    tz     type  source_dest
# 0         -6.0   A       America/Chicago  airport  OurAirports
# 1         -6.0   A       America/Chicago  airport  OurAirports
# 2         -5.0   U      America/New_York  airport  OurAirports
# 3         -5.0   A      America/New_York  airport  OurAirports
# 4         -6.0   A       America/Chicago  airport  OurAirports
# 5         -6.0   A       America/Chicago  airport  OurAirports
# 6         -6.0   A       America/Chicago  airport  OurAirports
# 7         -6.0   A       America/Chicago  airport  OurAirports
# 8         -5.0   U        America/Nassau  airport  OurAirports
# 9         -5.0   U        America/Nassau  airport  OurAirports
# 10        -5.0   A      America/New_York  airport  OurAirports
# 11        -5.0   U        America/Nassau  airport  OurAirports
# 12        -5.0   U        America/Nassau  airport  OurAirports
# 13        -5.0   U        America/Nassau  airport  OurAirports
# 14        -5.0   A      America/New_York  airport  OurAirports
# 15        -5.0   U        America/Nassau  airport  OurAirports
# 16        -5.0   U        America/Nassau  airport  OurAirports
# 17        -5.0   A      America/New_York  airport  OurAirports
# 18        -3.0   N  America/Buenos_Aires  airport  OurAirports
# 19        -4.0   U       America/Curacao  airport  OurAirports
# 20        -5.0   A      America/New_York  airport  OurAirports
# 21        -5.0   A      America/New_York  airport  OurAirports
# 22        -6.0   A       America/Chicago  airport  OurAirports
# 23        -5.0   A      America/New_York  airport  OurAirports
# 24        -5.0   A      America/New_York  airport  OurAirports
# 25        -6.0   A       America/Chicago  airport  OurAirports
# 26        -5.0   A      America/New_York  airport  OurAirports
# 27        -5.0   A      America/New_York  airport  OurAirports
# 28        -5.0   A      America/New_York  airport  OurAirports
# 29        -5.0   A      America/New_York  airport  OurAirports
# ...        ...  ..                   ...      ...          ...
# 3528      -7.0   A        America/Denver  airport  OurAirports
# 3529      -6.0   A       America/Chicago  airport  OurAirports
# 3530      -5.0   A      America/New_York  airport  OurAirports
# 3531      -6.0   A       America/Chicago  airport  OurAirports
# 3532      -6.0   A       America/Chicago  airport  OurAirports
# 3533      -7.0   N       America/Phoenix  airport  OurAirports
# 3534      -6.0   A       America/Chicago  airport  OurAirports
# 3535      -5.0   A      America/New_York  airport  OurAirports
# 3536      -5.0   A      America/New_York  airport  OurAirports
# 3537      -5.0   A       America/Toronto  airport  OurAirports
# 3538      -5.0   A       America/Toronto  airport  OurAirports
# 3539      -8.0   A     America/Vancouver  airport  OurAirports
# 3540      -7.0   A      America/Edmonton  airport  OurAirports
# 3541      -5.0   A       America/Toronto  airport  OurAirports
# 3542      -5.0   A       America/Toronto  airport  OurAirports
# 3543      -5.0   A       America/Toronto  airport  OurAirports
# 3544      -5.0   A       America/Toronto  airport  OurAirports
# 3545      -5.0   A      America/New_York  airport  OurAirports
# 3546      -6.0   A       America/Chicago  airport  OurAirports
# 3547      -4.0   A       America/Halifax  airport  OurAirports
# 3548      -5.0   A       America/Toronto  airport  OurAirports
# 3549      -5.0   A       America/Toronto  airport  OurAirports
# 3550      -5.0   A       America/Toronto  airport  OurAirports
# 3551      -5.0   A       America/Toronto  airport  OurAirports
# 3552      -5.0   A       America/Toronto  airport  OurAirports
# 3553      -8.0   A     America/Vancouver  airport  OurAirports
# 3554      -7.0   A      America/Edmonton  airport  OurAirports
# 3555      -5.0   A       America/Toronto  airport  OurAirports
# 3556      -6.0   S   America/Mexico_City  airport  OurAirports
# 3557      -6.0   A       America/Chicago  airport  OurAirports
#
# [3558 rows x 20 columns]

# %%
one_trsfr_allroutes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3558 entries, 0 to 3557
# Data columns (total 20 columns):
# layover          3558 non-null object
# layover_id       3558 non-null float64
# dest             3558 non-null object
# dest_id          3558 non-null object
# source_source    3558 non-null object
# source_id        3558 non-null object
# id               3553 non-null float64
# name             3553 non-null object
# city             3553 non-null object
# country          3553 non-null object
# iata             3553 non-null object
# icao             3553 non-null object
# latitude         3553 non-null float64
# longitude        3553 non-null float64
# altitude         3553 non-null float64
# timezone         3553 non-null float64
# dst              3553 non-null object
# tz               3553 non-null object
# type             3553 non-null object
# source_dest      3553 non-null object
# dtypes: float64(6), object(14)
# memory usage: 583.7+ KB

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in one_trsfr_allroutes.iterrows():
    
    if row['iata'] not in airport_set: 
        popup_string = row['city'] + ' (' + row['source_source'] + ')'
        marker = folium.CircleMarker(38.034, -84.500, color='MidnightBlue',
                                     fill_color='MidnightBlue', radius = 5, popup=popup_string )
        marker.add_to(lex_air)
        airport_set.add(row['source_source'])
        
   
        
lex_air
lex_air.save('one transfer.html')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-0c0aab0d3525> in <module>()
#       9         popup_string = row['city'] + ' (' + row['source_source'] + ')'
#      10         marker = folium.CircleMarker(38.034, -84.500, color='MidnightBlue',
# ---> 11                                      fill_color='MidnightBlue', radius = 5, popup=popup_string )
#      12         marker.add_to(lex_air)
#      13         airport_set.add(row['source_source'])
#
# TypeError: __init__() got multiple values for argument 'radius'

# %%
layover2_direct=one_trsfr_allroutes.dest.unique()
layover2_direct
# Out:
# array(['BRL', 'DEC', 'LWB', 'MCN', 'MEI', 'MSL', 'PIB', 'TUP', 'BIM',
#        'ELH', 'EYW', 'FPO', 'GGT', 'GHB', 'MCO', 'MHH', 'TCB', 'TPA',
#        'EZE', 'CUR', 'AZO', 'CHA', 'CID', 'CRW', 'CVG', 'EVV', 'FWA',
#        'GSO', 'GSP', 'LAN', 'LEX', 'MBS', 'MSP', 'ROA', 'SYR', 'TYS',
#        'XNA', 'MSY', 'ATL', 'CLT', 'DFW', 'LHR', 'MIA', 'ORD', 'PHL',
#        'PHX', 'ABE', 'AGS', 'ALB', 'ANU', 'AUA', 'AUS', 'AVL', 'AVP',
#        'BDL', 'BHM', 'BNA', 'BOS', 'BTR', 'BUF', 'BWI', 'BZE', 'CAE',
#        'CAK', 'CDG', 'CHO', 'CHS', 'CLE', 'CMH', 'CUN', 'CZM', 'DAB',
#        'DAY', 'DCA', 'DEN', 'DSM', 'DTW', 'DUB', 'EWN', 'EWR', 'FAY',
#        'FCO', 'FLL', 'FLO', 'FRA', 'GCM', 'GNV', 'GPT', 'GRU', 'HHH',
#        'HPN', 'HSV', 'HTS', 'IAD', 'IAH', 'ILM', 'IND', 'JAN', 'JAX',
#        'JFK', 'LAS', 'LAX', 'LGA', 'LIR', 'LIT', 'LYH', 'MBJ', 'MCI',
#        'MDT', 'MEM', 'MEX', 'MGM', 'MHT', 'MKE', 'MLB', 'MOB', 'MYR',
#        'NAS', 'OAJ', 'OMA', 'ORF', 'PBI', 'PDX', 'PGV', 'PHF', 'PIT',
#        'PLS', 'PNS', 'PUJ', 'PVD', 'PWM', 'RDU', 'RIC', 'ROC', 'RSW',
#        'SAN', 'SAT', 'SAV', 'SBY', 'SDF', 'SEA', 'SFO', 'SJD', 'SJO',
#        'SJU', 'SLC', 'SMF', 'SRQ', 'STL', 'STT', 'SXM', 'TLH', 'TRI',
#        'UVF', 'VPS', 'YOW', 'YUL', 'YYZ', 'BGR', 'BTV', 'ISP', 'YHZ',
#        'ABI', 'ABQ', 'ACT', 'AEX', 'AGU', 'AMA', 'BJX', 'BMI', 'BNE',
#        'BOG', 'BPT', 'BRO', 'CCS', 'CLL', 'CMI', 'COS', 'COU', 'CRP',
#        'CUU', 'DRO', 'ELP', 'FAR', 'FAT', 'FSD', 'FSM', 'GCK', 'GDL',
#        'GGG', 'GIG', 'GJT', 'GRI', 'GRK', 'GRR', 'GUA', 'HNL', 'HOU',
#        'ICN', 'ICT', 'JLN', 'LAW', 'LBB', 'LCH', 'LFT', 'LIM', 'LRD',
#        'MAD', 'MAF', 'MFE', 'MHK', 'MLI', 'MLM', 'MLU', 'MSN', 'MTY',
#        'MZT', 'NRT', 'OGG', 'OKC', 'ONT', 'PBC', 'PIA', 'PSP', 'PTY',
#        'PVR', 'QRO', 'RAP', 'RNO', 'ROW', 'RTB', 'SAF', 'SAL', 'SCL',
#        'SGF', 'SHV', 'SJC', 'SJT', 'SLP', 'SNA', 'SPI', 'SPS', 'TRC',
#        'TUL', 'TUS', 'TXK', 'TYR', 'YEG', 'YVR', 'YYC', 'ZCL', 'PAP',
#        'DOH', 'ALO', 'AMM', 'ART', 'AUH', 'CWA', 'DBQ', 'DUS', 'FNT',
#        'GRB', 'HKG', 'LSE', 'MAN', 'MQT', 'PEK', 'PVG', 'RST', 'SUX',
#        'TOL', 'TVC', 'TXL', 'YKF', 'YQB', 'YQR', 'YWG', 'YXU', 'ABY',
#        'ATW', 'BQK', 'BRU', 'CSG', 'DAL', 'DHN', 'ECP', 'GTR', 'MDW',
#        'MUC', 'SBN', 'STR', 'VLD', 'DEL', 'ANC', 'DXB', 'KIN', 'MDE',
#        'ORH', 'POS', 'SDQ', 'SWF', 'AMS', 'BDA', 'BON', 'BSB', 'JNB',
#        'LOS', 'MGA', 'SAP', 'TGU', 'UIO', 'ZRH', 'APN', 'BGM', 'CIU',
#        'ELM', 'ERI', 'ESC', 'ITH', 'NGO', 'PLN', 'SCE', 'ABR', 'BIL',
#        'BIS', 'BJI', 'BOI', 'BRD', 'BZN', 'DIK', 'DLH', 'FCA', 'GEG',
#        'GFK', 'GTF', 'HIB', 'HLN', 'IMT', 'INL', 'ISN', 'LNK', 'MOT',
#        'MSO', 'PSC', 'RHI', 'YXE', 'ARN', 'CPH', 'OSL', 'TTN', 'ILG',
#        'KEF', 'OAK', 'PBG', 'IAG', 'RFD', 'YNG', 'LCK', 'BLV', 'CKB',
#        'HGR', 'OWB', 'PSM', 'WAW', 'VCT', 'ACY', 'AXM', 'BQN', 'CTG',
#        'LBE', 'STI', 'TLC', 'ZSA', 'VIE', 'LUK', 'DME', 'IST', 'ACA',
#        'BFL', 'CME', 'DGO', 'HOB', 'HRL', 'HUX', 'MID', 'OAX', 'SLW',
#        'TAM', 'VER', 'VSA', 'ZIH', 'ZLO', 'CMX', 'EAU', 'FOE', 'MKG',
#        'PAH', 'STC', 'ATY'], dtype=object)

# %%
Final_dest = routes[routes['source'].isin(layover2_direct)]
Final_dest
# Out:
#       airline  airline_id source  source_id dest  dest_id codeshare  stops  \
# 5          2B       410.0    DME     4029.0  KZN   2990.0       NaN      0
# 6          2B       410.0    DME     4029.0  NBC   6969.0       NaN      0
# 7          2B       410.0    DME     4029.0  TGK      NaN       NaN      0
# 8          2B       410.0    DME     4029.0  UUA   6160.0       NaN      0
# 69         2I      8359.0    LIM     2789.0  AYP   2786.0       NaN      0
# 70         2I      8359.0    LIM     2789.0  CUZ   2812.0       NaN      0
# 71         2I      8359.0    LIM     2789.0  HUU   6067.0       NaN      0
# 72         2I      8359.0    LIM     2789.0  PCL   2781.0       NaN      0
# 73         2I      8359.0    LIM     2789.0  TPP   2806.0       NaN      0
# 103        2K      1338.0    BOG     2709.0  GYE   2673.0       NaN      0
# 104        2K      1338.0    BOG     2709.0  UIO   2688.0       NaN      0
# 112        2K      1338.0    UIO     2688.0  BOG   2709.0       NaN      0
# 113        2K      1338.0    UIO     2688.0  GYE   2673.0       NaN      0
# 114        2K      1338.0    UIO     2688.0  OCC   2670.0       NaN      0
# 123        2L      2750.0    ZRH     1678.0  BDS   1506.0       NaN      0
# 124        2L      2750.0    ZRH     1678.0  BOD   1264.0       NaN      0
# 125        2L      2750.0    ZRH     1678.0  BRS    490.0       NaN      0
# 126        2L      2750.0    ZRH     1678.0  LCA   1197.0       NaN      0
# 127        2L      2750.0    ZRH     1678.0  LPA   1054.0       NaN      0
# 128        2L      2750.0    ZRH     1678.0  RMF   4197.0       NaN      0
# 130        2N      3652.0    ARN      737.0  GEV    715.0       NaN      0
# 131        2N      3652.0    ARN      737.0  HAD    709.0       NaN      0
# 132        2N      3652.0    ARN      737.0  JKG    688.0       NaN      0
# 133        2N      3652.0    ARN      737.0  KRF    718.0       NaN      0
# 134        2N      3652.0    ARN      737.0  KSD   5595.0       NaN      0
# 135        2N      3652.0    ARN      737.0  LYC    719.0       NaN      0
# 136        2N      3652.0    ARN      737.0  MHQ    442.0       NaN      0
# 137        2N      3652.0    ARN      737.0  OER    722.0       NaN      0
# 138        2N      3652.0    ARN      737.0  POR    448.0       NaN      0
# 139        2N      3652.0    ARN      737.0  TRF    664.0       NaN      0
# ...       ...         ...    ...        ...  ...      ...       ...    ...
# 67162      ZH      4611.0    PVG     3406.0  XIY   3379.0         Y      0
# 67451      ZI        21.0    CDG     1382.0  ALG    210.0       NaN      0
# 67452      ZI        21.0    CDG     1382.0  FAO   1626.0       NaN      0
# 67453      ZI        21.0    CDG     1382.0  ORN    231.0       NaN      0
# 67513      ZK      2607.0    ATY     5721.0  MSP   3858.0       NaN      0
# 67514      ZK      2607.0    ATY     5721.0  PIR   5761.0       NaN      0
# 67522      ZK      2607.0    DEN     3751.0  AIA   7067.0       NaN      0
# 67523      ZK      2607.0    DEN     3751.0  ALS   7073.0       NaN      0
# 67524      ZK      2607.0    DEN     3751.0  BFF   5723.0       NaN      0
# 67525      ZK      2607.0    DEN     3751.0  CEZ   4338.0       NaN      0
# 67526      ZK      2607.0    DEN     3751.0  CYS   3804.0       NaN      0
# 67527      ZK      2607.0    DEN     3751.0  DDC   5733.0       NaN      0
# 67528      ZK      2607.0    DEN     3751.0  EAR   6129.0       NaN      0
# 67529      ZK      2607.0    DEN     3751.0  FMN   3743.0       NaN      0
# 67530      ZK      2607.0    DEN     3751.0  LBF   5748.0       NaN      0
# 67531      ZK      2607.0    DEN     3751.0  LBL   4341.0       NaN      0
# 67532      ZK      2607.0    DEN     3751.0  MCK   7068.0       NaN      0
# 67533      ZK      2607.0    DEN     3751.0  PGA   4124.0       NaN      0
# 67534      ZK      2607.0    DEN     3751.0  PIR   5761.0       NaN      0
# 67535      ZK      2607.0    DEN     3751.0  RIW   6881.0       NaN      0
# 67536      ZK      2607.0    DEN     3751.0  SHR   5769.0       NaN      0
# 67544      ZK      2607.0    LAX     3484.0  IGM   6132.0       NaN      0
# 67545      ZK      2607.0    LAX     3484.0  MCE   7122.0       NaN      0
# 67546      ZK      2607.0    LAX     3484.0  PRC   3446.0       NaN      0
# 67547      ZK      2607.0    LAX     3484.0  VIS   7121.0       NaN      0
# 67553      ZK      2607.0    MSP     3858.0  ATY   5721.0       NaN      0
# 67557      ZK      2607.0    PHX     3462.0  PGA   4124.0       NaN      0
# 67558      ZK      2607.0    PHX     3462.0  SOW   7078.0       NaN      0
# 67559      ZK      2607.0    PHX     3462.0  SVC   6135.0       NaN      0
# 67659      ZM     19016.0    DME     4029.0  FRU   2912.0       NaN      0
#
#       equipment
# 5           CR2
# 6           CR2
# 7           CR2
# 8           CR2
# 69          142
# 70      142 141
# 71          141
# 72      143 146
# 73      142 146
# 103         319
# 104     319 320
# 112     319 320
# 113         319
# 114         319
# 123         100
# 124         100
# 125         100
# 126         319
# 127         319
# 128         319
# 130         ATP
# 131         SF3
# 132     ATP SF3
# 133         ATP
# 134         SF3
# 135         ATP
# 136         SF3
# 137         ATR
# 138         SF3
# 139         SF3
# ...         ...
# 67162       320
# 67451       319
# 67452       319
# 67453       319
# 67513       BE1
# 67514       BE1
# 67522       BE1
# 67523   BE1 BEH
# 67524       BE1
# 67525       BE1
# 67526   BEH BE1
# 67527   BEH BE1
# 67528       EM2
# 67529       BE1
# 67530       BE1
# 67531   BE1 BEH
# 67532       BEH
# 67533       BE1
# 67534       BE1
# 67535       EM2
# 67536       EM2
# 67544       BE1
# 67545       BE1
# 67546       BE1
# 67547       BE1
# 67553       BE1
# 67557       BE1
# 67558       BE1
# 67559       BE1
# 67659       734
#
# [26262 rows x 9 columns]

# %%
Final_dest=Final_dest[['source','source_id','dest','dest_id']]

# %%
Final_dest.columns=['layover2','layover_id2','dest','dest_id']

# %%
Final_dest.head()
# Out:
#    layover2  layover_id2 dest  dest_id
# 5       DME       4029.0  KZN   2990.0
# 6       DME       4029.0  NBC   6969.0
# 7       DME       4029.0  TGK      NaN
# 8       DME       4029.0  UUA   6160.0
# 69      LIM       2789.0  AYP   2786.0

# %%
two_trsfr_routes= one_trsfr_allroutes [['source_source','source_id','layover','layover_id','dest','dest_id']]
two_trsfr_routes.columns=['source','source_id','layover','layover_id', 'layover2', 'layover_id2']
two_trsfr_routes
# Out:
#      source source_id layover  layover_id layover2 layover_id2
# 0       LEX    4017.0     ORD      3830.0      BRL        5726
# 1       LEX    4017.0     ORD      3830.0      DEC        4042
# 2       LEX    4017.0     ATL      3682.0      LWB        6958
# 3       LEX    4017.0     ATL      3682.0      MCN        3754
# 4       LEX    4017.0     ATL      3682.0      MEI        4335
# 5       LEX    4017.0     ATL      3682.0      MSL        5756
# 6       LEX    4017.0     ATL      3682.0      PIB        5759
# 7       LEX    4017.0     ATL      3682.0      TUP        5773
# 8       LEX    4017.0     FLL      3533.0      BIM        1937
# 9       LEX    4017.0     FLL      3533.0      ELH        1943
# 10      LEX    4017.0     FLL      3533.0      EYW        3875
# 11      LEX    4017.0     FLL      3533.0      FPO        1948
# 12      LEX    4017.0     FLL      3533.0      GGT        1941
# 13      LEX    4017.0     FLL      3533.0      GHB        1944
# 14      LEX    4017.0     FLL      3533.0      MCO        3878
# 15      LEX    4017.0     FLL      3533.0      MHH        1930
# 16      LEX    4017.0     FLL      3533.0      TCB        1934
# 17      LEX    4017.0     FLL      3533.0      TPA        3646
# 18      LEX    4017.0     DFW      3670.0      EZE        3988
# 19      LEX    4017.0     CLT      3876.0      CUR        2897
# 20      LEX    4017.0     ATL      3682.0      AZO        4039
# 21      LEX    4017.0     ATL      3682.0      CHA        3578
# 22      LEX    4017.0     ATL      3682.0      CID        4043
# 23      LEX    4017.0     ATL      3682.0      CRW        4285
# 24      LEX    4017.0     ATL      3682.0      CVG        3488
# 25      LEX    4017.0     ATL      3682.0      EVV        4018
# 26      LEX    4017.0     ATL      3682.0      FWA        4041
# 27      LEX    4017.0     ATL      3682.0      GSO        4008
# 28      LEX    4017.0     ATL      3682.0      GSP        4034
# 29      LEX    4017.0     ATL      3682.0      LAN        3544
# ...     ...       ...     ...         ...      ...         ...
# 3528    LEX    4017.0     MSP      3858.0      DEN        3751
# 3529    LEX    4017.0     MSP      3858.0      MCI        3458
# 3530    LEX    4017.0     MSP      3858.0      MCO        3878
# 3531    LEX    4017.0     MSP      3858.0      MDW        3747
# 3532    LEX    4017.0     MSP      3858.0      MKE        3717
# 3533    LEX    4017.0     MSP      3858.0      PHX        3462
# 3534    LEX    4017.0     MSP      3858.0      STL        3678
# 3535    LEX    4017.0     ATL      3682.0      JFK        3797
# 3536    LEX    4017.0     ATL      3682.0      LGA        3697
# 3537    LEX    4017.0     ATL      3682.0      YYZ         193
# 3538    LEX    4017.0     DFW      3670.0      YUL         146
# 3539    LEX    4017.0     DFW      3670.0      YVR         156
# 3540    LEX    4017.0     DFW      3670.0      YYC         178
# 3541    LEX    4017.0     DFW      3670.0      YYZ         193
# 3542    LEX    4017.0     DTW      3645.0      YYZ         193
# 3543    LEX    4017.0     FLL      3533.0      YUL         146
# 3544    LEX    4017.0     FLL      3533.0      YYZ         193
# 3545    LEX    4017.0     LGA      3697.0      ATL        3682
# 3546    LEX    4017.0     LGA      3697.0      MSY        3861
# 3547    LEX    4017.0     LGA      3697.0      YHZ          73
# 3548    LEX    4017.0     LGA      3697.0      YUL         146
# 3549    LEX    4017.0     LGA      3697.0      YYZ         193
# 3550    LEX    4017.0     MSP      3858.0      YUL         146
# 3551    LEX    4017.0     MSP      3858.0      YYZ         193
# 3552    LEX    4017.0     ORD      3830.0      YUL         146
# 3553    LEX    4017.0     ORD      3830.0      YVR         156
# 3554    LEX    4017.0     ORD      3830.0      YYC         178
# 3555    LEX    4017.0     ORD      3830.0      YYZ         193
# 3556    LEX    4017.0     ORD      3830.0      MEX        1824
# 3557    LEX    4017.0     MSP      3858.0      ATY        5721
#
# [3558 rows x 6 columns]

# %%
two_trsfr=two_trsfr_routes.join(Final_dest,how='right',on='layover2',lsuffix='two_trsfr_routes',rsuffix='Final_dest')
two_trsfr.head()
# Out:
#       layover2 source source_id layover  layover_id layover2two_trsfr_routes  \
# 3557         5    NaN       NaN     NaN         NaN                      NaN
# 3557         6    NaN       NaN     NaN         NaN                      NaN
# 3557         7    NaN       NaN     NaN         NaN                      NaN
# 3557         8    NaN       NaN     NaN         NaN                      NaN
# 3557        69    NaN       NaN     NaN         NaN                      NaN
#
#      layover_id2two_trsfr_routes layover2Final_dest  layover_id2Final_dest  \
# 3557                         NaN                DME                 4029.0
# 3557                         NaN                DME                 4029.0
# 3557                         NaN                DME                 4029.0
# 3557                         NaN                DME                 4029.0
# 3557                         NaN                LIM                 2789.0
#
#      dest  dest_id
# 3557  KZN   2990.0
# 3557  NBC   6969.0
# 3557  TGK      NaN
# 3557  UUA   6160.0
# 3557  AYP   2786.0

# %%
two_trsfr=two_trsfr[['layover2Final_dest','layover_id2Final_dest','dest','dest_id']]

# %%
two_trsfr['source']='LEX'
two_trsfr['source_id']='4017.0'

# %%
two_trsfr.columns=['layover2', 'layover2_id','dest', 'dest_id', 'source','source_id']
two_trsfr
# Out:
#      layover2  layover2_id dest  dest_id source source_id
# 3557      DME       4029.0  KZN   2990.0    LEX    4017.0
# 3557      DME       4029.0  NBC   6969.0    LEX    4017.0
# 3557      DME       4029.0  TGK      NaN    LEX    4017.0
# 3557      DME       4029.0  UUA   6160.0    LEX    4017.0
# 3557      LIM       2789.0  AYP   2786.0    LEX    4017.0
# 3557      LIM       2789.0  CUZ   2812.0    LEX    4017.0
# 3557      LIM       2789.0  HUU   6067.0    LEX    4017.0
# 3557      LIM       2789.0  PCL   2781.0    LEX    4017.0
# 3557      LIM       2789.0  TPP   2806.0    LEX    4017.0
# 3557      BOG       2709.0  GYE   2673.0    LEX    4017.0
# 3557      BOG       2709.0  UIO   2688.0    LEX    4017.0
# 3557      UIO       2688.0  BOG   2709.0    LEX    4017.0
# 3557      UIO       2688.0  GYE   2673.0    LEX    4017.0
# 3557      UIO       2688.0  OCC   2670.0    LEX    4017.0
# 3557      ZRH       1678.0  BDS   1506.0    LEX    4017.0
# 3557      ZRH       1678.0  BOD   1264.0    LEX    4017.0
# 3557      ZRH       1678.0  BRS    490.0    LEX    4017.0
# 3557      ZRH       1678.0  LCA   1197.0    LEX    4017.0
# 3557      ZRH       1678.0  LPA   1054.0    LEX    4017.0
# 3557      ZRH       1678.0  RMF   4197.0    LEX    4017.0
# 3557      ARN        737.0  GEV    715.0    LEX    4017.0
# 3557      ARN        737.0  HAD    709.0    LEX    4017.0
# 3557      ARN        737.0  JKG    688.0    LEX    4017.0
# 3557      ARN        737.0  KRF    718.0    LEX    4017.0
# 3557      ARN        737.0  KSD   5595.0    LEX    4017.0
# 3557      ARN        737.0  LYC    719.0    LEX    4017.0
# 3557      ARN        737.0  MHQ    442.0    LEX    4017.0
# 3557      ARN        737.0  OER    722.0    LEX    4017.0
# 3557      ARN        737.0  POR    448.0    LEX    4017.0
# 3557      ARN        737.0  TRF    664.0    LEX    4017.0
# ...       ...          ...  ...      ...    ...       ...
# 3557      PVG       3406.0  XIY   3379.0    LEX    4017.0
# 3557      CDG       1382.0  ALG    210.0    LEX    4017.0
# 3557      CDG       1382.0  FAO   1626.0    LEX    4017.0
# 3557      CDG       1382.0  ORN    231.0    LEX    4017.0
# 3557      ATY       5721.0  MSP   3858.0    LEX    4017.0
# 3557      ATY       5721.0  PIR   5761.0    LEX    4017.0
# 3557      DEN       3751.0  AIA   7067.0    LEX    4017.0
# 3557      DEN       3751.0  ALS   7073.0    LEX    4017.0
# 3557      DEN       3751.0  BFF   5723.0    LEX    4017.0
# 3557      DEN       3751.0  CEZ   4338.0    LEX    4017.0
# 3557      DEN       3751.0  CYS   3804.0    LEX    4017.0
# 3557      DEN       3751.0  DDC   5733.0    LEX    4017.0
# 3557      DEN       3751.0  EAR   6129.0    LEX    4017.0
# 3557      DEN       3751.0  FMN   3743.0    LEX    4017.0
# 3557      DEN       3751.0  LBF   5748.0    LEX    4017.0
# 3557      DEN       3751.0  LBL   4341.0    LEX    4017.0
# 3557      DEN       3751.0  MCK   7068.0    LEX    4017.0
# 3557      DEN       3751.0  PGA   4124.0    LEX    4017.0
# 3557      DEN       3751.0  PIR   5761.0    LEX    4017.0
# 3557      DEN       3751.0  RIW   6881.0    LEX    4017.0
# 3557      DEN       3751.0  SHR   5769.0    LEX    4017.0
# 3557      LAX       3484.0  IGM   6132.0    LEX    4017.0
# 3557      LAX       3484.0  MCE   7122.0    LEX    4017.0
# 3557      LAX       3484.0  PRC   3446.0    LEX    4017.0
# 3557      LAX       3484.0  VIS   7121.0    LEX    4017.0
# 3557      MSP       3858.0  ATY   5721.0    LEX    4017.0
# 3557      PHX       3462.0  PGA   4124.0    LEX    4017.0
# 3557      PHX       3462.0  SOW   7078.0    LEX    4017.0
# 3557      PHX       3462.0  SVC   6135.0    LEX    4017.0
# 3557      DME       4029.0  FRU   2912.0    LEX    4017.0
#
# [26262 rows x 6 columns]

# %%
# join the destination airports.  Here we need to use the suffixes option, because 
# the column names overlap, and we want to distinguish between source and dest
two_trsfr_allroutes = pd.merge(two_trsfr, airports, 
                      left_on='dest_id', 
                      right_on='id', 
                      how='left', 
                      suffixes=['_source','_dest'])
two_trsfr_allroutes
# Out:
#       layover2  layover2_id dest dest_id source_source source_id      id  \
# 0          DME       4029.0  KZN    2990           LEX    4017.0  2990.0
# 1          DME       4029.0  NBC    6969           LEX    4017.0  6969.0
# 2          DME       4029.0  TGK     NaN           LEX    4017.0     NaN
# 3          DME       4029.0  UUA    6160           LEX    4017.0  6160.0
# 4          LIM       2789.0  AYP    2786           LEX    4017.0  2786.0
# 5          LIM       2789.0  CUZ    2812           LEX    4017.0  2812.0
# 6          LIM       2789.0  HUU    6067           LEX    4017.0  6067.0
# 7          LIM       2789.0  PCL    2781           LEX    4017.0  2781.0
# 8          LIM       2789.0  TPP    2806           LEX    4017.0  2806.0
# 9          BOG       2709.0  GYE    2673           LEX    4017.0  2673.0
# 10         BOG       2709.0  UIO    2688           LEX    4017.0  2688.0
# 11         UIO       2688.0  BOG    2709           LEX    4017.0  2709.0
# 12         UIO       2688.0  GYE    2673           LEX    4017.0  2673.0
# 13         UIO       2688.0  OCC    2670           LEX    4017.0  2670.0
# 14         ZRH       1678.0  BDS    1506           LEX    4017.0  1506.0
# 15         ZRH       1678.0  BOD    1264           LEX    4017.0  1264.0
# 16         ZRH       1678.0  BRS     490           LEX    4017.0   490.0
# 17         ZRH       1678.0  LCA    1197           LEX    4017.0  1197.0
# 18         ZRH       1678.0  LPA    1054           LEX    4017.0  1054.0
# 19         ZRH       1678.0  RMF    4197           LEX    4017.0  4197.0
# 20         ARN        737.0  GEV     715           LEX    4017.0   715.0
# 21         ARN        737.0  HAD     709           LEX    4017.0   709.0
# 22         ARN        737.0  JKG     688           LEX    4017.0   688.0
# 23         ARN        737.0  KRF     718           LEX    4017.0   718.0
# 24         ARN        737.0  KSD    5595           LEX    4017.0  5595.0
# 25         ARN        737.0  LYC     719           LEX    4017.0   719.0
# 26         ARN        737.0  MHQ     442           LEX    4017.0   442.0
# 27         ARN        737.0  OER     722           LEX    4017.0   722.0
# 28         ARN        737.0  POR     448           LEX    4017.0   448.0
# 29         ARN        737.0  TRF     664           LEX    4017.0   664.0
# ...        ...          ...  ...     ...           ...       ...     ...
# 26232      PVG       3406.0  XIY    3379           LEX    4017.0  3379.0
# 26233      CDG       1382.0  ALG     210           LEX    4017.0   210.0
# 26234      CDG       1382.0  FAO    1626           LEX    4017.0  1626.0
# 26235      CDG       1382.0  ORN     231           LEX    4017.0   231.0
# 26236      ATY       5721.0  MSP    3858           LEX    4017.0  3858.0
# 26237      ATY       5721.0  PIR    5761           LEX    4017.0  5761.0
# 26238      DEN       3751.0  AIA    7067           LEX    4017.0  7067.0
# 26239      DEN       3751.0  ALS    7073           LEX    4017.0  7073.0
# 26240      DEN       3751.0  BFF    5723           LEX    4017.0  5723.0
# 26241      DEN       3751.0  CEZ    4338           LEX    4017.0  4338.0
# 26242      DEN       3751.0  CYS    3804           LEX    4017.0  3804.0
# 26243      DEN       3751.0  DDC    5733           LEX    4017.0  5733.0
# 26244      DEN       3751.0  EAR    6129           LEX    4017.0     NaN
# 26245      DEN       3751.0  FMN    3743           LEX    4017.0  3743.0
# 26246      DEN       3751.0  LBF    5748           LEX    4017.0  5748.0
# 26247      DEN       3751.0  LBL    4341           LEX    4017.0  4341.0
# 26248      DEN       3751.0  MCK    7068           LEX    4017.0  7068.0
# 26249      DEN       3751.0  PGA    4124           LEX    4017.0  4124.0
# 26250      DEN       3751.0  PIR    5761           LEX    4017.0  5761.0
# 26251      DEN       3751.0  RIW    6881           LEX    4017.0  6881.0
# 26252      DEN       3751.0  SHR    5769           LEX    4017.0  5769.0
# 26253      LAX       3484.0  IGM    6132           LEX    4017.0     NaN
# 26254      LAX       3484.0  MCE    7122           LEX    4017.0  7122.0
# 26255      LAX       3484.0  PRC    3446           LEX    4017.0  3446.0
# 26256      LAX       3484.0  VIS    7121           LEX    4017.0  7121.0
# 26257      MSP       3858.0  ATY    5721           LEX    4017.0  5721.0
# 26258      PHX       3462.0  PGA    4124           LEX    4017.0  4124.0
# 26259      PHX       3462.0  SOW    7078           LEX    4017.0  7078.0
# 26260      PHX       3462.0  SVC    6135           LEX    4017.0     NaN
# 26261      DME       4029.0  FRU    2912           LEX    4017.0  2912.0
#
#                                                     name          city  \
# 0                            Kazan International Airport         Kazan
# 1                                      Begishevo Airport   Nizhnekamsk
# 2                                                    NaN           NaN
# 3                                        Bugulma Airport       Bugulma
# 4            Coronel FAP Alfredo Mendivil Duarte Airport      Ayacucho
# 5         Alejandro Velasco Astete International Airport         Cuzco
# 6          Alferez Fap David Figueroa Fernandini Airport       Huánuco
# 7      Cap FAP David Abenzur Rengifo International Ai...      Pucallpa
# 8      Cadete FAP Guillermo Del Castillo Paredes Airport      Tarapoto
# 9           José Joaquín de Olmedo International Airport     Guayaquil
# 10                  Mariscal Sucre International Airport         Quito
# 11                       El Dorado International Airport        Bogota
# 12          José Joaquín de Olmedo International Airport     Guayaquil
# 13                         Francisco De Orellana Airport          Coca
# 14                            Brindisi – Salento Airport      Brindisi
# 15                             Bordeaux-Mérignac Airport      Bordeaux
# 16                                       Bristol Airport       Bristol
# 17                         Larnaca International Airport       Larnaca
# 18                                  Gran Canaria Airport  Gran Canaria
# 19                      Marsa Alam International Airport    Marsa Alam
# 20                                     Gällivare Airport     Gallivare
# 21                                      Halmstad Airport      Halmstad
# 22                                     Jönköping Airport   Joenkoeping
# 23                            Kramfors Sollefteå Airport      Kramfors
# 24                                      Karlstad Airport      Karlstad
# 25                                      Lycksele Airport      Lycksele
# 26                                     Mariehamn Airport     Mariehamn
# 27                                  Örnsköldsvik Airport  Ornskoldsvik
# 28                                          Pori Airport          Pori
# 29                              Sandefjord Airport, Torp    Sandefjord
# ...                                                  ...           ...
# 26232               Xi'an Xianyang International Airport         Xi'an
# 26233                          Houari Boumediene Airport        Algier
# 26234                                       Faro Airport          Faro
# 26235                                   Es Senia Airport          Oran
# 26236  Minneapolis-St Paul International/Wold-Chamber...   Minneapolis
# 26237                            Pierre Regional Airport        Pierre
# 26238                         Alliance Municipal Airport      Alliance
# 26239             San Luis Valley Regional Bergman Field       Alamosa
# 26240        Western Neb. Rgnl/William B. Heilig Airport   Scottsbluff
# 26241                           Cortez Municipal Airport        Cortez
# 26242                Cheyenne Regional Jerry Olson Field      Cheyenne
# 26243                        Dodge City Regional Airport    Dodge City
# 26244                                                NaN           NaN
# 26245                      Four Corners Regional Airport    Farmington
# 26246       North Platte Regional Airport Lee Bird Field  North Platte
# 26247               Liberal Mid-America Regional Airport       Liberal
# 26248                Mc Cook Ben Nelson Regional Airport        McCook
# 26249                             Page Municipal Airport          Page
# 26250                            Pierre Regional Airport        Pierre
# 26251                          Riverton Regional Airport   Riverton WY
# 26252                            Sheridan County Airport      Sheridan
# 26253                                                NaN           NaN
# 26254                     Merced Regional Macready Field        Merced
# 26255                               Ernest A. Love Field      Prescott
# 26256                          Visalia Municipal Airport       Visalia
# 26257                         Watertown Regional Airport     Watertown
# 26258                             Page Municipal Airport          Page
# 26259                          Show Low Regional Airport      Show Low
# 26260                                                NaN           NaN
# 26261                        Manas International Airport       Bishkek
#
#               country iata  icao   latitude   longitude  altitude  timezone  \
# 0              Russia  KZN  UWKD  55.606201   49.278702     411.0       3.0
# 1              Russia  NBC  UWKE  55.564701   52.092499     643.0       3.0
# 2                 NaN  NaN   NaN        NaN         NaN       NaN       NaN
# 3              Russia  UUA  UWKB  54.639999   52.801701     991.0       3.0
# 4                Peru  AYP  SPHO -13.154800  -74.204399    8917.0      -5.0
# 5                Peru  CUZ  SPZO -13.535700  -71.938797   10860.0      -5.0
# 6                Peru  HUU  SPNC  -9.878810  -76.204803    6070.0      -5.0
# 7                Peru  PCL  SPCL  -8.377940  -74.574303     513.0      -5.0
# 8                Peru  TPP  SPST  -6.508740  -76.373199     869.0      -5.0
# 9             Ecuador  GYE  SEGU  -2.157420  -79.883598      19.0      -5.0
# 10            Ecuador  UIO  SEQM  -0.129167  -78.357500    7841.0      -5.0
# 11           Colombia  BOG  SKBO   4.701590  -74.146900    8361.0      -5.0
# 12            Ecuador  GYE  SEGU  -2.157420  -79.883598      19.0      -5.0
# 13            Ecuador  OCC  SECO  -0.462886  -76.986801     834.0      -5.0
# 14              Italy  BDS  LIBR  40.657600   17.947001      47.0       1.0
# 15             France  BOD  LFBD  44.828300   -0.715556     162.0       1.0
# 16     United Kingdom  BRS  EGGD  51.382702   -2.719090     622.0       0.0
# 17             Cyprus  LCA  LCLK  34.875099   33.624901       8.0       2.0
# 18              Spain  LPA  GCLP  27.931900  -15.386600      78.0       0.0
# 19              Egypt  RMF  HEMA  25.557100   34.583698     251.0       2.0
# 20             Sweden  GEV  ESNG  67.132401   20.814600    1027.0       1.0
# 21             Sweden  HAD  ESMT  56.691101   12.820200     101.0       1.0
# 22             Sweden  JKG  ESGJ  57.757599   14.068700     741.0       1.0
# 23             Sweden  KRF  ESNK  63.048599   17.768900      34.0       1.0
# 24             Sweden  KSD  ESOK  59.444698   13.337400     352.0       1.0
# 25             Sweden  LYC  ESNL  64.548302   18.716200     705.0       1.0
# 26            Finland  MHQ  EFMA  60.122200   19.898199      17.0       2.0
# 27             Sweden  OER  ESNO  63.408298   18.990000     354.0       1.0
# 28            Finland  POR  EFPO  61.461700   21.799999      44.0       2.0
# 29             Norway  TRF  ENTO  59.186699   10.258600     286.0       1.0
# ...               ...  ...   ...        ...         ...       ...       ...
# 26232           China  XIY  ZLXY  34.447102  108.751999    1572.0       8.0
# 26233         Algeria  ALG  DAAG  36.691002    3.215410      82.0       1.0
# 26234        Portugal  FAO  LPFR  37.014400   -7.965910      24.0       0.0
# 26235         Algeria  ORN  DAOO  35.623901   -0.621183     295.0       1.0
# 26236   United States  MSP  KMSP  44.882000  -93.221802     841.0      -6.0
# 26237   United States  PIR  KPIR  44.382702 -100.286003    1744.0      -6.0
# 26238   United States  AIA  KAIA  42.053200 -102.804001    3931.0      -7.0
# 26239   United States  ALS  KALS  37.434898 -105.866997    7539.0      -7.0
# 26240   United States  BFF  KBFF  41.874001 -103.596001    3967.0      -7.0
# 26241   United States  CEZ  KCEZ  37.303001 -108.627998    5918.0      -7.0
# 26242   United States  CYS  KCYS  41.155701 -104.811996    6159.0      -7.0
# 26243   United States  DDC  KDDC  37.763401  -99.965599    2594.0      -6.0
# 26244             NaN  NaN   NaN        NaN         NaN       NaN       NaN
# 26245   United States  FMN  KFMN  36.741199 -108.230003    5506.0      -7.0
# 26246   United States  LBF  KLBF  41.126202 -100.683998    2777.0      -6.0
# 26247   United States  LBL  KLBL  37.044201 -100.959999    2885.0      -6.0
# 26248   United States  MCK  KMCK  40.206299 -100.592003    2583.0      -6.0
# 26249   United States  PGA  KPGA  36.926102 -111.447998    4316.0      -7.0
# 26250   United States  PIR  KPIR  44.382702 -100.286003    1744.0      -6.0
# 26251   United States  RIW  KRIW  43.064201 -108.459999    5525.0      -7.0
# 26252   United States  SHR  KSHR  44.769199 -106.980003    4021.0      -7.0
# 26253             NaN  NaN   NaN        NaN         NaN       NaN       NaN
# 26254   United States  MCE  KMCE  37.284698 -120.514000     155.0      -8.0
# 26255   United States  PRC  KPRC  34.654499 -112.419998    5045.0      -7.0
# 26256   United States  VIS  KVIS  36.318699 -119.392998     295.0      -8.0
# 26257   United States  ATY  KATY  44.914001  -97.154701    1749.0      -6.0
# 26258   United States  PGA  KPGA  36.926102 -111.447998    4316.0      -7.0
# 26259   United States  SOW  KSOW  34.265499 -110.005997    6415.0      -7.0
# 26260             NaN  NaN   NaN        NaN         NaN       NaN       NaN
# 26261      Kyrgyzstan  FRU  UAFM  43.061298   74.477600    2058.0       6.0
#
#        dst                   tz     type  source_dest
# 0        N        Europe/Moscow  airport  OurAirports
# 1        N        Europe/Moscow  airport  OurAirports
# 2      NaN                  NaN      NaN          NaN
# 3        N        Europe/Moscow  airport  OurAirports
# 4        U         America/Lima  airport  OurAirports
# 5        U         America/Lima  airport  OurAirports
# 6        U         America/Lima  airport  OurAirports
# 7        U         America/Lima  airport  OurAirports
# 8        U         America/Lima  airport  OurAirports
# 9        U    America/Guayaquil  airport  OurAirports
# 10       U    America/Guayaquil  airport  OurAirports
# 11       U       America/Bogota  airport  OurAirports
# 12       U    America/Guayaquil  airport  OurAirports
# 13       U    America/Guayaquil  airport  OurAirports
# 14       E          Europe/Rome  airport  OurAirports
# 15       E         Europe/Paris  airport  OurAirports
# 16       E        Europe/London  airport  OurAirports
# 17       E         Asia/Nicosia  airport  OurAirports
# 18       E      Atlantic/Canary  airport  OurAirports
# 19       U         Africa/Cairo  airport  OurAirports
# 20       E     Europe/Stockholm  airport  OurAirports
# 21       E     Europe/Stockholm  airport  OurAirports
# 22       E     Europe/Stockholm  airport  OurAirports
# 23       E     Europe/Stockholm  airport  OurAirports
# 24       E     Europe/Stockholm  airport  OurAirports
# 25       E     Europe/Stockholm  airport  OurAirports
# 26       E     Europe/Mariehamn  airport  OurAirports
# 27       E     Europe/Stockholm  airport  OurAirports
# 28       E      Europe/Helsinki  airport  OurAirports
# 29       E          Europe/Oslo  airport  OurAirports
# ...    ...                  ...      ...          ...
# 26232    U        Asia/Shanghai  airport  OurAirports
# 26233    N       Africa/Algiers  airport  OurAirports
# 26234    E        Europe/Lisbon  airport  OurAirports
# 26235    N       Africa/Algiers  airport  OurAirports
# 26236    A      America/Chicago  airport  OurAirports
# 26237    A      America/Chicago  airport  OurAirports
# 26238    A       America/Denver  airport  OurAirports
# 26239    A       America/Denver  airport  OurAirports
# 26240    A       America/Denver  airport  OurAirports
# 26241    A       America/Denver  airport  OurAirports
# 26242    A       America/Denver  airport  OurAirports
# 26243    A      America/Chicago  airport  OurAirports
# 26244  NaN                  NaN      NaN          NaN
# 26245    A       America/Denver  airport  OurAirports
# 26246    A      America/Chicago  airport  OurAirports
# 26247    A      America/Chicago  airport  OurAirports
# 26248    A      America/Chicago  airport  OurAirports
# 26249    A      America/Phoenix  airport  OurAirports
# 26250    A      America/Chicago  airport  OurAirports
# 26251    A       America/Denver  airport  OurAirports
# 26252    A       America/Denver  airport  OurAirports
# 26253  NaN                  NaN      NaN          NaN
# 26254    A  America/Los_Angeles  airport  OurAirports
# 26255    A      America/Phoenix  airport  OurAirports
# 26256    A  America/Los_Angeles  airport  OurAirports
# 26257    A      America/Chicago  airport  OurAirports
# 26258    A      America/Phoenix  airport  OurAirports
# 26259    A      America/Phoenix  airport  OurAirports
# 26260  NaN                  NaN      NaN          NaN
# 26261    U         Asia/Bishkek  airport  OurAirports
#
# [26262 rows x 20 columns]

# %%
two_trsfr_allroutes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26262 entries, 0 to 26261
# Data columns (total 20 columns):
# layover2         26262 non-null object
# layover2_id      26262 non-null float64
# dest             26262 non-null object
# dest_id          26232 non-null object
# source_source    26262 non-null object
# source_id        26262 non-null object
# id               26097 non-null float64
# name             26097 non-null object
# city             26097 non-null object
# country          26097 non-null object
# iata             26097 non-null object
# icao             26097 non-null object
# latitude         26097 non-null float64
# longitude        26097 non-null float64
# altitude         26097 non-null float64
# timezone         26097 non-null float64
# dst              26097 non-null object
# tz               26086 non-null object
# type             26097 non-null object
# source_dest      26097 non-null object
# dtypes: float64(6), object(14)
# memory usage: 4.2+ MB

# %%
# create a basic map, centered on Lexington
lex_air = folium.Map(
    location=[38.034,-84.500],
    tiles='Stamen Toner',
    zoom_start=4
)

# %%
# Define some empty sets
airport_set = set()
route_set = set()

# Make sure we don't add duplicates, especially for the origins
for name, row in two_trsfr_allroutes.iterrows():
    
    if row['source_source'] not in airport_set: 
        popup_string = row['city'] + ' (' + row['source_source'] + ')'
        marker = folium.CircleMarker(38.034,-84.500, 
                                     color='DarkCyan',
                                     fill_color='DarkCyan', 
                                     radius=5, popup=popup_string)
        marker.add_to(lex_air)
        airport_set.add(row['source_source'])
        
lex_air
lex_air.save('two transfer.html')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-133-51b1933ff515> in <module>()
#      11                                      color='DarkCyan',
#      12                                      fill_color='DarkCyan',
# ---> 13                                      radius=5, popup=popup_string)
#      14         marker.add_to(lex_air)
#      15         airport_set.add(row['source_source'])
#
# TypeError: __init__() got multiple values for argument 'radius'
